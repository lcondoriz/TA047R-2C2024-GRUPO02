# %% [markdown]
# <a href="https://colab.research.google.com/github/Celestine-Raveneau/Celestine-Raveneau/blob/main/EJ3_TP_Ciencia_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Organización de Datos**
#
# Trabajo Práctico N°1: TLC Trip Record Data
#
# Grupo 02 - 2C2024
#
# Cátedra Ing. Rodriguez, Juan Manuel
#
# #EJ 3 - Airbnb ROME

# %% [markdown]
# #Ruta del archivo a procesar

# %% [markdown]
# ### Includes

# %%
# !pip install plotly_express

import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 30)

import seaborn as sns
import numpy as np
import plotly_express as px
import matplotlib.pyplot as plt

from scipy.spatial.distance import mahalanobis

from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from xgboost import XGBRegressor

from matplotlib import pyplot as plt
from scipy.stats import chi2_contingency
import pyarrow.parquet as pq
from datetime import date
# Out:
# Requirement already satisfied: plotly_express in /usr/local/lib/python3.10/dist-packages (0.4.1)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from plotly_express) (2.2.2)
# Requirement already satisfied: plotly>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from plotly_express) (5.24.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from plotly_express) (0.14.4)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.10/dist-packages (from plotly_express) (1.13.1)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.10/dist-packages (from plotly_express) (0.5.6)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.10/dist-packages (from plotly_express) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.20.0->plotly_express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.20.0->plotly_express) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.20.0->plotly_express) (2024.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5->plotly_express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.1.0->plotly_express) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.1.0->plotly_express) (24.1)

# %% [markdown]
# ### Getting the datasets from the drive

# %%
from google.colab import drive
drive.mount('/content/drive')

listings_short=pd.read_csv('/content/drive/MyDrive/Ta047-tp_2do_cuat_2024_grupo_2/Data/EJ3/listings.csv')
listings_long=pd.read_csv('/content/drive/MyDrive/Ta047-tp_2do_cuat_2024_grupo_2/Data/EJ3/listings_long_version.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Choosing which file to work on

# %% [markdown]
# ### Files available for Rome in the website
# - listings
#   - short version
#   - long version with more columns
# - reviews
#   - long version (id, date, comment)
#   - short version (id, date)
# -neighbourhood (should give us neighbourhood_group for each neighbourhood but the column is empty)
# -neighbourhoods.geojson (says which coordinates belong to which neighbourhood
#
# The files that could interest us are the long and short version of listings
#
# ### Outline
# We will analyse the content of both to choose if we should work with the long version, the short version or a combination of the two.
#
# We will then continue with a breif data analysis to see what variables interest us most before move on with the data cleaning and data transformation
#
# Once all of this is done we will be able to train different models with our datas and compare the results.

# %% [markdown]
# Let's first see if there is the same number of data in each file.

# %%
print("Number of lignes in the short version :", listings_short.shape[0])
print("Number of lignes in the long version :", listings_long.shape[0])
# Out:
# Number of lignes in the short version : 32243
# Number of lignes in the long version : 34061

# %% [markdown]
# #### Comparison of the number of NaNs in each file.

# %%
nan_percent_short = listings_short.isna().mean() * 100
nan_count_long = listings_long.isna().mean() * 100

common_columns = listings_short.columns.intersection(listings_long.columns)

nan_comparison = pd.DataFrame({
    'NaN % (listing_short)': nan_percent_short[common_columns],
    'NaN % (listing_long)': nan_count_long[common_columns]
})

print(nan_comparison)
# Out:
#                                 NaN % (listing_short)  NaN % (listing_long)
# id                                           0.000000              0.000000
# name                                         0.000000              0.000000
# host_id                                      0.000000              0.000000
# host_name                                    0.003101              0.000000
# neighbourhood                                0.000000             43.912392
# latitude                                     0.000000              0.000000
# longitude                                    0.000000              0.000000
# room_type                                    0.000000              0.000000
# price                                       10.994634             11.053698
# minimum_nights                               0.000000              0.000000
# number_of_reviews                            0.000000              0.000000
# last_review                                 14.133300             14.890931
# reviews_per_month                           14.133300             14.890931
# calculated_host_listings_count               0.000000              0.000000
# availability_365                             0.000000              0.000000
# number_of_reviews_ltm                        0.000000              0.000000
# license                                     71.389139             67.132498

# %% [markdown]
# All of the columns for the short version are in the long one too.
#
# When I first analysed this I did not realise that the neighbourhood column had a "cleaned" version in listings_long and thus combining both files would not add much value. Thus I did an analisis of how much lines are in commun between both files, which I left below.
#
# However with this information in mind, we can directly pick listings_long.

# %% [markdown]
# ####  Inner join to see how many lines are in commun

# %% [markdown]
# To choose if a combination of both files would be possible, we need to know how many lines they have in commun.
#
# We are going to do an inner join, for which we need not to have any duplicate considering the commun columns with no NaNs between the two files (excluding id)

# %% [markdown]
# Transforming price into an int in the long version so that both versions have the same data type for price

# %%
listings_long['price'] = listings_long['price'].str.replace('$', '').str.replace(',', '').astype(float)

# %% [markdown]
# Finding out the commun columns without NaNs

# %%
# Find common columns between listings_long and listings_short
common_columns = list(set(listings_long.columns).intersection(set(listings_short.columns)))

# Filter out columns with NaNs in either listings_long or listings_short
columns_without_nans = []
for col in common_columns:
  if listings_long[col].notna().all() and listings_short[col].notna().all():
    columns_without_nans.append(col)

columns_without_nans.remove('id')
print("Common columns without NaNs:")
print(columns_without_nans)
# Out:
# Common columns without NaNs:
# ['minimum_nights', 'number_of_reviews_ltm', 'number_of_reviews', 'room_type', 'name', 'longitude', 'latitude', 'host_id', 'calculated_host_listings_count', 'availability_365']

# %% [markdown]
# Cheking for duplicate considering thoses columns.

# %%
pd.set_option('display.max_columns', 20)
duplicates = listings_long[listings_long.duplicated(subset=columns_without_nans, keep=False)]

print("Number of duplicates :", len(duplicates))
print(duplicates[['id', 'description']])
id_duplicate = duplicates['id'].iloc[0]
# Out:
# Number of duplicates : 2
#                         id                                        description
# 32086  1192070747028414787  Relax with the whole family at this peaceful p...
# 32167  1192748198713818341  You’ll be charmed by this adorable place to st...

# %% [markdown]
# The datas are duplicates considering only the columns we will join upon (but not considering all columns), thus we will create a data frame without one of them for the join

# %% [markdown]
# Getting rid of the "duplicate"

# %%
listings_long_for_join = listings_long.drop(listings_long[listings_long['id'] == id_duplicate ].index)

# %% [markdown]
# Same for the short version

# %%
pd.set_option('display.max_columns', 20)
duplicates = listings_short[listings_short.duplicated(subset=['name','host_id','room_type','longitude','latitude','minimum_nights','number_of_reviews','availability_365','calculated_host_listings_count','number_of_reviews_ltm'], keep=False)]

print("Number of duplicates :", len(duplicates))
print(duplicates[['id']])
id_duplicate = id_duplicate = duplicates['id'].iloc[0]
# Out:
# Number of duplicates : 2
#                         id
# 31994  1172977129296583972
# 31995  1172998319181271741

# %%
listings_short_for_join = listings_short.drop(listings_long[listings_long['id'] == id_duplicate].index)

# %% [markdown]
# Now that we are sure not to have any duplicates let's see how many line we have in each data set and if we combine both

# %%
#Calculating the number of line in commun
#Since the ids are not the same for the appartement we are considering that if two appartements have the same host_name and price it is the same appartment.
columns_to_merge_on = ['name','host_id','room_type','longitude','latitude','minimum_nights','number_of_reviews','availability_365','calculated_host_listings_count','number_of_reviews_ltm']
matching_rows = pd.merge(
    listings_long_for_join[columns_to_merge_on],
    listings_short_for_join[columns_to_merge_on],
    on=columns_to_merge_on,
    how='inner'
)
print("Number of lignes in commun to both versions :", len(matching_rows))
# Out:
# Number of lignes in commun to both versions : 2515

# %% [markdown]
# As we can see there are very few lines I commun between both files, thus we don't have the option of combining both and we have to choose one.

# %% [markdown]
# #Análisis Exploratorio y preprocesamiento de datos

# %% [markdown]
# ##Droping the columns that don't interest us

# %% [markdown]
# Considering the important number of columns we will be deleting those that are redondant or that don't give relevant information before further analysing the data.

# %% [markdown]
# #### Correlation between price and other numerical variables

# %%
# Select the 'price' column and other relevant numerical columns
numerical_data = listings_long.select_dtypes(include=np.number)
price_corr = numerical_data.corr()['price']

# Sort the correlations in descending order
price_corr = price_corr.sort_values(ascending=False)

# Create a bar plot to visualize the correlations
plt.figure(figsize=(10, 6))
price_corr.plot(kind='bar')
plt.title('Correlation of Price with Other Variables')
plt.xlabel('Variables')
plt.ylabel('Correlation Coefficient')
plt.show()

# %% [markdown]
# #### Looking at boxplot for each numerical variable to spot non-linear relations that wouldn't appear on the correlation graph but would stil be useful.

# %%
bin_listings_long = listings_long.copy()

def apply_cut_and_plot(bin_listings_long, target, bins=8):
    # Sélectionner les colonnes numériques sauf la colonne 'price'
    numeric_columns = bin_listings_long.select_dtypes(include=['float64', 'int64']).columns
    numeric_columns = numeric_columns.drop(target)

    for column in numeric_columns:
        # Appliquer pd.cut sur chaque colonne
        bin_listings_long[f'bin_{column}'] = pd.qcut(bin_listings_long[column], q=bins, duplicates='drop')

        # Replace NaN values with a separate category
        bin_listings_long[f'bin_{column}'] = bin_listings_long[f'bin_{column}'].cat.add_categories([-1]).fillna(-1)
        bin_listings_long[f'bin_{column}'] = bin_listings_long[f'bin_{column}'].cat.codes  # Get category codes

        # Tracer un boxplot
        sns.boxplot(x=f'bin_{column}', y=target, data=bin_listings_long)
        plt.yscale('log')
        plt.title(f'Boxplot of {target} by bin_{column}')
        plt.show()

# Utiliser la fonction sur ton DataFrame
apply_cut_and_plot(bin_listings_long, target='price')

# %% [markdown]
# #### Choice of columns being kept or not
# - Columns being deleted
#   - Redondant :
#     - with neighbourhood_cleansed : 'neighbourhood'
#     - with minimum_nights and maximum_nights : 'minimum_minimum_nights',
#   'maximum_minimum_nights', 'minimum_maximum_nights',
#   'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm'
#     - with availability_365 : 'has_availability', 'availability_30', 'availability_60', 'availability_90'
#     - with reviews_per_month : 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review', 'last_review'
#     - with 'host_total_listings_count' : 'host_listings_count'
#
#   - Irelevant :
#
#   'listing_url', 'scrape_id', 'last_scraped', 'source', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'calendar_updated', 'calendar_last_scraped', 'license', 'instant_bookable'
#
#   - Almost not correlated to price
#
#   'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'review_scores_rating', 'review_scores_accuracy','review_scores_cleanliness', 'review_scores_checkin',
#   'review_scores_communication',
#   'review_scores_value', 'reviews_per_month',  'availability_365', 'number_of_reviews'
#
# - Column being replaced by numerical values :
#
# 'amenities' : counting the number of element in the list
#
# - Columns being kept :
#
# 'host_id', 'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price', 'minimum_nights', 'maximum_nights', 'host_total_listings_count',  'review_scores_location'

# %%
df = listings_long

#Deleting info relative to host
df = df.drop(['host_url', 'host_name', 'host_since', 'host_location', 'host_about',
       'host_response_time', 'host_response_rate', 'host_acceptance_rate',
       'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
       'host_neighbourhood', 'host_listings_count', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified',
       'calculated_host_listings_count_entire_homes',
       'calculated_host_listings_count_private_rooms',
       'calculated_host_listings_count_shared_rooms'], axis=1)

#Deleting some info relativ to min-max night
df = df.drop(['minimum_minimum_nights',
       'maximum_minimum_nights', 'minimum_maximum_nights',
       'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm'], axis=1)

#Deleting columns relativ to availability
df = df.drop(['calendar_updated', 'has_availability',
       'availability_30', 'availability_60', 'availability_90', 'availability_365', 'calendar_last_scraped'], axis=1)

#Deleting columns relativ to reviews
df = df.drop(['number_of_reviews_ltm', 'number_of_reviews_l30d',
       'first_review', 'last_review',
       'calculated_host_listings_count',
       'reviews_per_month', 'number_of_reviews',
       'review_scores_rating', 'review_scores_accuracy','review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_value'], axis=1)

#Deleting other columns
df = df.drop(['description','neighbourhood','license',
       'instant_bookable','listing_url','scrape_id', 'last_scraped', 'source', 'name',
       'description', 'neighborhood_overview', 'picture_url'], axis=1)

#Replacing by numerical value
df['amenities_number'] = df['amenities'].apply(lambda x: len(x.split(',')) if isinstance(x, str) else 0)
df = df.drop(['amenities'], axis=1)

# %%
df.columns
# Out:
# Index(['id', 'host_id', 'host_total_listings_count', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'price', 'minimum_nights',
#        'maximum_nights', 'review_scores_location', 'amenities_number'],
#       dtype='object')

# %% [markdown]
# ## Analisis of the link between price and the other data

# %%
df_analisis = df.copy()

# %% [markdown]
# ### Numerical datas correlation with price

# %% [markdown]
# Calculating the correlation between the price and the other numerical values

# %% [markdown]
# Corelation matrix

# %%
# Select the 'price' column and other relevant numerical columns
numerical_data = df_analisis.select_dtypes(include=np.number)
price_corr = numerical_data.corr()['price']

# Sort the correlations in descending order
price_corr = price_corr.sort_values(ascending=False)

# Print the correlations with the 'price' column
print(price_corr)

# Create a bar plot to visualize the correlations
plt.figure(figsize=(10, 6))
price_corr.plot(kind='bar')
plt.title('Correlation of Price with Other Variables')
plt.xlabel('Variables')
plt.ylabel('Correlation Coefficient')
plt.show()
# Out:
# price                           1.000000
# bathrooms                       0.167722
# accommodates                    0.149195
# bedrooms                        0.148861
# beds                            0.126583
# host_total_listings_count       0.082339
# maximum_nights                  0.057505
# review_scores_location          0.053704
# latitude                        0.014637
# host_id                         0.012013
# id                             -0.004999
# amenities_number               -0.006698
# minimum_nights                 -0.008404
# longitude                      -0.011121
# neighbourhood_group_cleansed         NaN
# Name: price, dtype: float64

# %%
numeric_cols = df_analisis.select_dtypes(include='number')

corr_matrix = numeric_cols.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Corelation matrix')
plt.show()

# %% [markdown]
# We can see that price is not higly correlated to any numerical variable.
#
# The best result we have is with accomodates, bathrooms, bedrooms and beds.

# %% [markdown]
# ### Not numerical data

# %% [markdown]
# Creating a categorized price variable

# %%
# Binning price variable
bins = [0, 50, 100, 150, 200, 70000]
labels = ['<50', '50-100', '100-150', '150-200', '200+']
df_analisis['price_bins'] = pd.cut(df_analisis['price'], bins=bins, labels=labels, right=False)

# %% [markdown]
# #### Neighbourhood

# %% [markdown]
# We are first making a heatmap that shows how much elements there are for each price range in each neighbourhood.
#
# We apply a log scale to have a result that is easy to understand.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a contingency table
contingency_table = pd.crosstab(df_analisis['price_bins'], df_analisis['neighbourhood_cleansed'])
log_corr_matrix = np.log1p(contingency_table)  # log1p ajoute 1 pour éviter log(0)

# Create the heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(log_corr_matrix, annot=True, cmap='coolwarm')
plt.title('Heatmap of Price Range and Neighbourhood')
plt.xlabel('Neighbourhood')
plt.ylabel('Price Range')
plt.show()

# %% [markdown]
# To better visualize the price repartition in each neighbourhood, we are making a graph that categorizes price in 5 bins and then shows for each neigbourhood the pourcentage of appartement from this neighbourhood in each categorie.

# %%
# Calculate % of appartement in each categorie for each neighbourhood
grouped = df_analisis.groupby(['neighbourhood_cleansed', 'price_bins'],observed=True).size().unstack(fill_value=0)
percentage = grouped.div(grouped.sum(axis=1), axis=0) * 100

# Show graph
percentage = percentage.fillna(0)  # Remplacer NaN par 0
percentage.plot(kind='bar', stacked=True, figsize=(12, 8))

plt.title('Percentage of appartement from each neighbourhood in each price range')
plt.xlabel('Neighbourhood')
plt.ylabel('Percentage (%)')
plt.legend(title='Price ranges', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# This graph clearly shows us that the price of the appartment is correlated to the neigbourhood but it does not give us any values of "how correlated" it is.

# %% [markdown]
# We are going to do the same with property_type and room_type.

# %% [markdown]
# #### Property type

# %% [markdown]
# This one might be biased by the fact that some categories have only very few element thus the percentage are not very accurate.
#
# If we want to use property type in the model we will need to regroup elements into bigger categories.

# %% [markdown]
# Version withou grouping

# %%
# Calculate % of appartement in each categorie for each property type
grouped = df_analisis.groupby(['property_type', 'price_bins'],observed=True).size().unstack(fill_value=0)
percentage = grouped.div(grouped.sum(axis=1), axis=0) * 100

# Show graph
percentage = percentage.fillna(0)  # Remplacer NaN par 0
percentage.plot(kind='bar', stacked=True, figsize=(12, 8))

plt.title('Percentage of appartement of each property type in each price range')
plt.xlabel('Property type')
plt.ylabel('Percentage (%)')
plt.legend(title='Price ranges', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Grouping element in categorie with less then 50 elements into 'Other'

# %%
# Count the number of lignes with each possible value for property type
property_type_counts = df_analisis['property_type'].value_counts()
print(property_type_counts)

# Create a new dataframe where all elements in a categorie with less then 50 elements go into a new categorie 'other'
df_analisis['property_type_grouped'] = df_analisis['property_type']
for property_type in property_type_counts.index:
  if property_type_counts[property_type] < 50:
    df_analisis.loc[df['property_type'] == property_type, 'property_type_grouped'] = 'Other'

# Print the number of lignes with each possible value for the new categorie
property_type_grouped_counts = df_analisis['property_type_grouped'].value_counts()
#print(property_type_grouped_counts)

#Create a dataframe for the new categorie
df_property_type_grouped = df_analisis[['property_type_grouped','price_bins']]

#Print the new dataframe
print(df_property_type_grouped)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 29061                  Entire rental unit       200+
# 29062                        Entire condo       200+
# 29063                  Entire rental unit    150-200
# 29064         Private room in rental unit     50-100
# 29065         Private room in rental unit     50-100
# 29066                  Entire rental unit    100-150
# 29067                        Entire villa     50-100
# 29068                  Entire rental unit    150-200
# 29069                        Entire condo     50-100
# 29070                        Entire condo     50-100
# 29071                  Entire rental unit     50-100
# 29072                Entire vacation home    100-150
# 29073                         Entire home    150-200
# 29074                  Entire rental unit    150-200
# 29075         Private room in rental unit    150-200
# 29076                  Entire rental unit    150-200
# 29077                  Entire rental unit    150-200
# 29078                  Entire rental unit     50-100
# 29079                  Entire rental unit    100-150
# 29080                  Entire rental unit     50-100
# 29081   Private room in bed and breakfast        NaN
# 29082   Private room in bed and breakfast        NaN
# 29083                       Room in hotel        NaN
# 29084                        Entire condo       200+
# 29085                  Entire rental unit        NaN
# 29086         Private room in rental unit       200+
# 29087               Private room in condo     50-100
# 29088                  Entire rental unit     50-100
# 29089                        Entire condo       200+
# 29090                  Entire rental unit       200+
# 29091                  Entire rental unit       200+
# 29092                               Other     50-100
# 29093                  Entire rental unit       200+
# 29094                  Entire rental unit       200+
# 29095                       Room in hotel        NaN
# 29096                        Entire condo       200+
# 29097                  Entire rental unit       200+
# 29098         Private room in rental unit    100-150
# 29099                  Entire rental unit       200+
# 29100                  Entire rental unit    150-200
# 29101                  Entire rental unit    150-200
# 29102                       Room in hotel       200+
# 29103                       Room in hotel       200+
# 29104                       Room in hotel       200+
# 29105                       Room in hotel        NaN
# 29106                       Room in hotel       200+
# 29107                       Room in hotel       200+
# 29108                  Entire rental unit       200+
# 29109                  Entire rental unit       200+
# 29110                  Entire rental unit     50-100
# 29111                  Entire rental unit       200+
# 29112                  Entire rental unit       200+
# 29113         Private room in rental unit     50-100
# 29114                  Entire rental unit        NaN
# 29115                        Entire condo    100-150
# 29116                        Entire condo    150-200
# 29117                  Entire rental unit    150-200
# 29118                  Entire rental unit    100-150
# 29119                Entire vacation home    150-200
# 29120                        Entire condo     50-100
# 29121                  Entire rental unit    150-200
# 29122                  Entire rental unit        NaN
# 29123                        Entire condo    100-150
# 29124                        Entire condo    100-150
# 29125                        Entire condo    100-150
# 29126                  Entire rental unit     50-100
# 29127                  Entire rental unit    100-150
# 29128                  Entire rental unit    100-150
# 29129                  Entire rental unit    150-200
# 29130         Private room in rental unit        <50
# 29131         Private room in rental unit     50-100
# 29132         Private room in rental unit    100-150
# 29133  Private room in serviced apartment       200+
# 29134                  Entire rental unit        NaN
# 29135                  Entire rental unit    100-150
# 29136                  Entire rental unit    150-200
# 29137                  Entire rental unit     50-100
# 29138                        Entire condo       200+
# 29139         Private room in rental unit    100-150
# 29140                  Entire rental unit     50-100
# 29141                  Entire rental unit       200+
# 29142                  Entire rental unit    100-150
# 29143                  Entire rental unit       200+
# 29144                  Entire rental unit       200+
# 29145                  Entire rental unit    100-150
# 29146  Private room in serviced apartment       200+
# 29147                  Entire rental unit    150-200
# 29148                  Entire rental unit    100-150
# 29149                  Entire rental unit     50-100
# 29150                Entire vacation home    150-200
# 29151  Private room in serviced apartment       200+
# 29152  Private room in serviced apartment       200+
# 29153                  Entire rental unit    100-150
# 29154                  Entire rental unit    100-150
# 29155                  Entire rental unit       200+
# 29156                  Entire rental unit     50-100
# 29157                  Entire rental unit       200+
# 29158                  Entire rental unit     50-100
# 29159                  Entire rental unit    150-200
# 29160                         Entire home    100-150
# 29161                        Entire condo    150-200
# 29162                  Entire rental unit    100-150
# 29163                        Entire condo    150-200
# 29164                  Entire rental unit     50-100
# 29165                  Entire rental unit       200+
# 29166                  Entire rental unit     50-100
# 29167                  Entire rental unit    150-200
# 29168                        Entire condo    150-200
# 29169                        Entire condo     50-100
# 29170                  Entire rental unit       200+
# 29171                  Entire rental unit    100-150
# 29172                  Entire rental unit    100-150
# 29173                  Entire rental unit    100-150
# 29174                        Entire condo     50-100
# 29175                  Entire rental unit    100-150
# 29176                        Entire condo    100-150
# 29177                  Entire rental unit     50-100
# 29178                         Entire home    100-150
# 29179                  Entire rental unit     50-100
# 29180                  Entire rental unit    100-150
# 29181               Private room in condo     50-100
# 29182         Private room in rental unit     50-100
# 29183                         Entire home    100-150
# 29184                         Entire loft       200+
# 29185                  Entire rental unit       200+
# 29186                  Entire rental unit    100-150
# 29187         Private room in rental unit    100-150
# 29188                        Entire condo       200+
# 29189         Private room in rental unit    100-150
# 29190                  Entire rental unit       200+
# 29191                Private room in home     50-100
# 29192                           Tiny home     50-100
# 29193                         Entire loft    100-150
# 29194                  Entire rental unit     50-100
# 29195                  Entire rental unit    100-150
# 29196                  Entire rental unit       200+
# 29197                  Entire rental unit     50-100
# 29198                       Room in hotel    100-150
# 29199                  Entire rental unit    100-150
# 29200                  Entire rental unit     50-100
# 29201   Private room in bed and breakfast    100-150
# 29202                        Entire condo    100-150
# 29203                  Entire rental unit    100-150
# 29204                  Entire rental unit    150-200
# 29205                  Entire rental unit     50-100
# 29206                  Entire rental unit    100-150
# 29207                        Entire condo    100-150
# 29208                  Entire rental unit    100-150
# 29209         Private room in rental unit     50-100
# 29210                        Entire condo    100-150
# 29211   Private room in bed and breakfast    100-150
# 29212         Private room in rental unit     50-100
# 29213               Private room in condo    100-150
# 29214   Private room in bed and breakfast       200+
# 29215                  Entire rental unit    100-150
# 29216                  Entire rental unit       200+
# 29217                  Entire rental unit       200+
# 29218                  Entire rental unit    150-200
# 29219                  Entire rental unit    100-150
# 29220                        Entire condo    150-200
# 29221                  Entire rental unit       200+
# 29222                        Entire condo     50-100
# 29223         Private room in rental unit     50-100
# 29224         Private room in rental unit     50-100
# 29225                  Entire rental unit    100-150
# 29226   Private room in bed and breakfast        NaN
# 29227                  Entire rental unit    100-150
# 29228   Private room in bed and breakfast       200+
# 29229   Private room in bed and breakfast       200+
# 29230         Private room in rental unit     50-100
# 29231                  Entire rental unit    100-150
# 29232                  Entire rental unit       200+
# 29233                  Entire rental unit     50-100
# 29234                        Entire condo    100-150
# 29235                  Entire rental unit       200+
# 29236                  Entire rental unit     50-100
# 29237                  Entire rental unit    150-200
# 29238                  Entire rental unit    150-200
# 29239                        Entire condo       200+
# 29240                        Entire condo    100-150
# 29241                  Entire rental unit       200+
# 29242                  Entire rental unit        NaN
# 29243                  Entire rental unit       200+
# 29244                  Entire rental unit       200+
# 29245                  Entire rental unit    100-150
# 29246         Private room in rental unit     50-100
# 29247                  Entire rental unit    100-150
# 29248   Private room in bed and breakfast     50-100
# 29249                  Entire rental unit     50-100
# 29250                        Entire condo       200+
# 29251                  Entire rental unit       200+
# 29252                  Entire rental unit    100-150
# 29253                  Entire rental unit       200+
# 29254                  Entire rental unit     50-100
# 29255                  Entire rental unit        NaN
# 29256                  Entire rental unit    100-150
# 29257                  Entire rental unit     50-100
# 29258                  Entire rental unit     50-100
# 29259                  Entire rental unit    100-150
# 29260               Private room in condo    100-150
# 29261                        Entire condo     50-100
# 29262         Private room in rental unit    150-200
# 29263                  Entire rental unit       200+
# 29264                        Entire condo     50-100
# 29265                  Entire rental unit    100-150
# 29266                         Entire home    100-150
# 29267         Private room in rental unit     50-100
# 29268         Private room in rental unit     50-100
# 29269                  Entire rental unit    150-200
# 29270                         Entire home     50-100
# 29271                Entire vacation home    100-150
# 29272                  Entire rental unit    100-150
# 29273                  Entire rental unit    100-150
# 29274                  Entire rental unit    150-200
# 29275               Private room in condo     50-100
# 29276                  Entire rental unit    150-200
# 29277                  Entire rental unit    100-150
# 29278                  Entire rental unit    100-150
# 29279               Private room in condo     50-100
# 29280         Private room in rental unit    100-150
# 29281                  Entire rental unit       200+
# 29282                  Entire rental unit       200+
# 29283                  Entire rental unit       200+
# 29284                  Entire rental unit     50-100
# 29285                Entire vacation home    150-200
# 29286                  Entire rental unit       200+
# 29287                        Entire condo     50-100
# 29288                         Entire home    150-200
# 29289                        Entire condo       200+
# 29290                  Entire rental unit    100-150
# 29291                  Entire rental unit       200+
# 29292                        Entire condo     50-100
# 29293                  Entire rental unit     50-100
# 29294                  Entire rental unit    100-150
# 29295                  Entire rental unit     50-100
# 29296                  Entire rental unit     50-100
# 29297               Private room in condo     50-100
# 29298                  Entire rental unit       200+
# 29299                  Entire rental unit    100-150
# 29300                         Entire home     50-100
# 29301                  Entire rental unit    150-200
# 29302                  Entire rental unit     50-100
# 29303                  Entire rental unit       200+
# 29304                  Entire rental unit    100-150
# 29305                  Entire rental unit     50-100
# 29306                  Entire rental unit     50-100
# 29307                Private room in home       200+
# 29308                  Entire rental unit    100-150
# 29309                         Entire home    100-150
# 29310                  Entire rental unit    100-150
# 29311                  Entire rental unit     50-100
# 29312                        Entire condo       200+
# 29313   Private room in bed and breakfast        NaN
# 29314   Private room in bed and breakfast       200+
# 29315                  Entire rental unit    150-200
# 29316   Private room in bed and breakfast       200+
# 29317   Private room in bed and breakfast       200+
# 29318                        Entire condo    150-200
# 29319                        Entire condo       200+
# 29320   Private room in bed and breakfast       200+
# 29321                  Entire rental unit    100-150
# 29322                  Entire rental unit    100-150
# 29323                  Entire rental unit    100-150
# 29324                        Entire condo       200+
# 29325                  Entire rental unit     50-100
# 29326                        Entire condo     50-100
# 29327                  Entire rental unit    100-150
# 29328                Entire vacation home        NaN
# 29329                        Entire condo    150-200
# 29330                  Entire rental unit    100-150
# 29331                  Entire rental unit    100-150
# 29332         Private room in rental unit    100-150
# 29333                        Entire condo       200+
# 29334                        Entire condo    100-150
# 29335                  Entire rental unit       200+
# 29336                  Entire rental unit    150-200
# 29337                  Entire rental unit    150-200
# 29338                  Entire rental unit    100-150
# 29339                  Entire rental unit       200+
# 29340                  Entire rental unit    150-200
# 29341                  Entire rental unit    100-150
# 29342                         Entire loft     50-100
# 29343                  Entire rental unit     50-100
# 29344         Private room in rental unit    100-150
# 29345                  Entire rental unit       200+
# 29346                  Entire rental unit    100-150
# 29347                Entire vacation home    100-150
# 29348                  Entire rental unit    150-200
# 29349                  Entire rental unit    150-200
# 29350                        Entire condo     50-100
# 29351                  Entire rental unit     50-100
# 29352                  Entire rental unit       200+
# 29353                  Entire rental unit    100-150
# 29354                  Entire rental unit     50-100
# 29355                  Entire rental unit    100-150
# 29356                  Entire rental unit    100-150
# 29357                  Entire rental unit    100-150
# 29358                         Entire home    100-150
# 29359                  Entire rental unit     50-100
# 29360                  Entire rental unit       200+
# 29361                  Entire rental unit        <50
# 29362   Private room in bed and breakfast    100-150
# 29363                  Entire rental unit    100-150
# 29364   Private room in bed and breakfast     50-100
# 29365                Entire vacation home     50-100
# 29366                  Entire rental unit    100-150
# 29367                  Entire rental unit    100-150
# 29368                  Entire rental unit       200+
# 29369                  Entire rental unit     50-100
# 29370                  Entire rental unit        NaN
# 29371                  Entire rental unit       200+
# 29372                        Entire condo    100-150
# 29373                  Entire rental unit    150-200
# 29374                  Entire rental unit    100-150
# 29375                  Entire rental unit        NaN
# 29376                  Entire rental unit    100-150
# 29377                  Entire rental unit       200+
# 29378                  Entire rental unit    150-200
# 29379                        Entire condo    100-150
# 29380                  Entire rental unit    100-150
# 29381                  Entire rental unit    100-150
# 29382                  Entire rental unit       200+
# 29383         Private room in rental unit     50-100
# 29384                  Entire rental unit    100-150
# 29385                        Entire condo    150-200
# 29386                  Entire rental unit    150-200
# 29387                  Entire rental unit    100-150
# 29388                  Entire rental unit    100-150
# 29389                  Entire rental unit       200+
# 29390                  Entire rental unit     50-100
# 29391                  Entire rental unit       200+
# 29392                         Entire home    100-150
# 29393                         Entire home    150-200
# 29394                  Entire rental unit    100-150
# 29395                        Entire condo     50-100
# 29396                         Entire home       200+
# 29397                  Entire rental unit    150-200
# 29398                  Entire rental unit    100-150
# 29399                  Entire rental unit        NaN
# 29400   Private room in bed and breakfast     50-100
# 29401                Private room in home        <50
# 29402                        Entire condo    150-200
# 29403                  Entire rental unit     50-100
# 29404               Private room in condo     50-100
# 29405                Entire vacation home    100-150
# 29406                Entire vacation home    150-200
# 29407                        Entire condo    150-200
# 29408         Private room in rental unit     50-100
# 29409                        Entire condo    100-150
# 29410         Private room in rental unit    100-150
# 29411         Private room in rental unit    100-150
# 29412                  Entire rental unit       200+
# 29413                  Entire rental unit     50-100
# 29414                        Entire condo    100-150
# 29415                  Entire rental unit    100-150
# 29416                  Entire rental unit    100-150
# 29417                  Entire rental unit        NaN
# 29418                  Entire rental unit    150-200
# 29419                  Entire rental unit       200+
# 29420                        Entire condo    100-150
# 29421                  Entire rental unit     50-100
# 29422                  Entire rental unit    100-150
# 29423                  Entire rental unit       200+
# 29424                  Entire rental unit     50-100
# 29425                               Other     50-100
# 29426                  Entire rental unit     50-100
# 29427         Private room in rental unit     50-100
# 29428                  Entire rental unit       200+
# 29429                         Entire home    100-150
# 29430                  Entire rental unit    100-150
# 29431                  Entire rental unit    100-150
# 29432                  Entire rental unit    100-150
# 29433                  Entire rental unit       200+
# 29434                         Entire home     50-100
# 29435                  Entire rental unit       200+
# 29436                  Entire rental unit    100-150
# 29437                  Entire rental unit       200+
# 29438                  Entire rental unit       200+
# 29439         Private room in rental unit       200+
# 29440                         Entire home    100-150
# 29441         Private room in rental unit       200+
# 29442         Private room in rental unit    100-150
# 29443                  Entire rental unit    100-150
# 29444                  Entire rental unit     50-100
# 29445                        Entire condo    150-200
# 29446                  Entire rental unit       200+
# 29447   Private room in bed and breakfast    150-200
# 29448                  Entire rental unit    100-150
# 29449              Room in boutique hotel       200+
# 29450                  Entire rental unit     50-100
# 29451                  Entire rental unit    150-200
# 29452   Private room in bed and breakfast    100-150
# 29453                  Entire rental unit     50-100
# 29454                  Entire rental unit       200+
# 29455                  Entire rental unit    150-200
# 29456                  Entire rental unit     50-100
# 29457                               Other       200+
# 29458                  Entire rental unit     50-100
# 29459                        Entire condo       200+
# 29460                  Entire rental unit    100-150
# 29461                  Entire rental unit    100-150
# 29462                  Entire rental unit     50-100
# 29463                  Entire rental unit    100-150
# 29464                  Entire rental unit       200+
# 29465                  Entire rental unit    150-200
# 29466         Private room in rental unit    100-150
# 29467                        Entire condo    100-150
# 29468         Private room in rental unit     50-100
# 29469         Private room in rental unit    100-150
# 29470         Private room in rental unit    100-150
# 29471                  Entire rental unit     50-100
# 29472                  Entire rental unit    100-150
# 29473                         Entire home     50-100
# 29474                  Entire rental unit     50-100
# 29475                         Entire home     50-100
# 29476                  Entire rental unit    100-150
# 29477                  Entire rental unit       200+
# 29478                Entire vacation home       200+
# 29479   Private room in bed and breakfast       200+
# 29480                  Entire rental unit       200+
# 29481                  Entire rental unit       200+
# 29482                  Entire rental unit    150-200
# 29483                        Entire condo       200+
# 29484                  Entire rental unit    100-150
# 29485                  Entire rental unit     50-100
# 29486                  Entire rental unit    150-200
# 29487                  Entire rental unit       200+
# 29488                        Entire condo        NaN
# 29489                        Entire condo    100-150
# 29490                  Entire rental unit     50-100
# 29491                  Entire rental unit     50-100
# 29492         Private room in rental unit    150-200
# 29493                  Entire rental unit       200+
# 29494                  Entire rental unit     50-100
# 29495                  Entire rental unit        NaN
# 29496                  Entire rental unit    100-150
# 29497                  Entire rental unit       200+
# 29498                  Entire rental unit    150-200
# 29499                        Entire condo    150-200
# 29500                Entire vacation home    100-150
# 29501                  Entire rental unit       200+
# 29502         Private room in rental unit       200+
# 29503                  Entire rental unit    100-150
# 29504                  Entire rental unit    150-200
# 29505                  Entire rental unit     50-100
# 29506                  Entire rental unit    100-150
# 29507                  Entire rental unit    150-200
# 29508                  Entire rental unit    100-150
# 29509                  Entire rental unit    100-150
# 29510                Entire vacation home       200+
# 29511   Private room in bed and breakfast    150-200
# 29512         Private room in rental unit     50-100
# 29513                  Entire rental unit    150-200
# 29514   Private room in bed and breakfast    150-200
# 29515                  Entire rental unit       200+
# 29516         Private room in rental unit        NaN
# 29517   Private room in bed and breakfast       200+
# 29518   Private room in bed and breakfast       200+
# 29519   Private room in bed and breakfast       200+
# 29520                         Entire home    150-200
# 29521                  Entire rental unit     50-100
# 29522                  Entire rental unit    100-150
# 29523                  Entire rental unit     50-100
# 29524                Entire vacation home    150-200
# 29525   Private room in bed and breakfast     50-100
# 29526                  Entire rental unit    100-150
# 29527                  Entire rental unit       200+
# 29528                        Entire villa       200+
# 29529                  Entire rental unit    100-150
# 29530                  Entire rental unit     50-100
# 29531                         Entire home       200+
# 29532                  Entire rental unit    150-200
# 29533                  Entire rental unit    100-150
# 29534                  Entire rental unit     50-100
# 29535                  Entire rental unit       200+
# 29536                  Entire rental unit    100-150
# 29537   Private room in bed and breakfast     50-100
# 29538                Entire vacation home     50-100
# 29539                  Entire rental unit    100-150
# 29540         Private room in rental unit        NaN
# 29541                        Entire condo       200+
# 29542                Private room in home     50-100
# 29543                  Entire rental unit    100-150
# 29544         Private room in rental unit    150-200
# 29545                  Entire rental unit     50-100
# 29546                  Entire rental unit    150-200
# 29547                  Entire rental unit       200+
# 29548                  Entire rental unit     50-100
# 29549                  Entire rental unit    150-200
# 29550                        Entire condo       200+
# 29551                  Entire rental unit       200+
# 29552                  Entire rental unit    100-150
# 29553                  Entire rental unit        <50
# 29554                  Entire rental unit    100-150
# 29555                  Entire rental unit       200+
# 29556                  Entire rental unit    100-150
# 29557                  Entire rental unit       200+
# 29558                  Entire rental unit    150-200
# 29559                  Entire rental unit    100-150
# 29560          Private room in guesthouse        NaN
# 29561          Private room in guesthouse        NaN
# 29562          Private room in guesthouse    100-150
# 29563          Private room in guesthouse    100-150
# 29564                  Entire rental unit       200+
# 29565                  Entire rental unit    100-150
# 29566                  Entire rental unit    100-150
# 29567                  Entire rental unit    150-200
# 29568              Room in boutique hotel    150-200
# 29569                  Entire rental unit    150-200
# 29570                  Entire rental unit       200+
# 29571                  Entire rental unit    150-200
# 29572                  Entire rental unit     50-100
# 29573                  Entire rental unit    100-150
# 29574         Private room in rental unit    100-150
# 29575                        Entire condo    100-150
# 29576                  Entire rental unit    100-150
# 29577         Private room in rental unit        NaN
# 29578                Entire vacation home    150-200
# 29579                        Entire condo       200+
# 29580                  Entire rental unit       200+
# 29581                  Entire rental unit    100-150
# 29582                  Entire rental unit       200+
# 29583                  Entire rental unit    100-150
# 29584                  Entire rental unit    150-200
# 29585                  Entire rental unit       200+
# 29586         Private room in rental unit       200+
# 29587                  Entire rental unit    150-200
# 29588                  Entire rental unit    100-150
# 29589                  Entire rental unit    150-200
# 29590                  Entire rental unit     50-100
# 29591                  Entire rental unit       200+
# 29592                Entire vacation home    150-200
# 29593                Entire vacation home     50-100
# 29594                  Entire rental unit       200+
# 29595                        Entire condo    150-200
# 29596                         Entire home     50-100
# 29597                  Entire rental unit    100-150
# 29598   Private room in bed and breakfast     50-100
# 29599                Entire vacation home       200+
# 29600                  Entire rental unit    100-150
# 29601                  Entire rental unit    100-150
# 29602                  Entire rental unit    150-200
# 29603                  Entire rental unit    100-150
# 29604                  Entire rental unit    150-200
# 29605                  Entire rental unit    100-150
# 29606                  Entire rental unit       200+
# 29607                  Entire rental unit       200+
# 29608   Private room in bed and breakfast     50-100
# 29609   Private room in bed and breakfast     50-100
# 29610   Private room in bed and breakfast     50-100
# 29611                  Entire rental unit       200+
# 29612                Entire vacation home       200+
# 29613                  Entire rental unit       200+
# 29614                  Entire rental unit       200+
# 29615                Entire vacation home    150-200
# 29616                  Entire rental unit    100-150
# 29617                         Entire home     50-100
# 29618                         Entire home    100-150
# 29619                  Entire rental unit    100-150
# 29620   Private room in bed and breakfast    150-200
# 29621                         Entire home     50-100
# 29622   Private room in bed and breakfast     50-100
# 29623         Private room in rental unit     50-100
# 29624         Private room in rental unit     50-100
# 29625                  Entire rental unit       200+
# 29626                  Entire rental unit    100-150
# 29627                  Entire rental unit       200+
# 29628         Private room in rental unit     50-100
# 29629         Private room in rental unit    100-150
# 29630         Private room in rental unit     50-100
# 29631                  Entire rental unit     50-100
# 29632                        Entire condo       200+
# 29633                  Entire rental unit     50-100
# 29634                  Entire rental unit    150-200
# 29635                  Entire rental unit    100-150
# 29636                  Entire rental unit     50-100
# 29637         Private room in rental unit    150-200
# 29638                  Entire rental unit       200+
# 29639                  Entire rental unit       200+
# 29640                         Entire home    100-150
# 29641                        Entire condo     50-100
# 29642                  Entire rental unit       200+
# 29643                Entire vacation home       200+
# 29644                  Entire rental unit    150-200
# 29645                  Entire rental unit    150-200
# 29646                  Entire rental unit       200+
# 29647                         Entire loft    100-150
# 29648                  Entire rental unit       200+
# 29649         Private room in rental unit     50-100
# 29650                  Entire rental unit     50-100
# 29651                  Entire rental unit       200+
# 29652                        Entire condo     50-100
# 29653                  Entire rental unit    100-150
# 29654                  Entire rental unit    100-150
# 29655                  Entire rental unit    150-200
# 29656                  Entire rental unit       200+
# 29657                  Entire rental unit       200+
# 29658                         Entire home     50-100
# 29659                  Entire rental unit    100-150
# 29660               Private room in condo    100-150
# 29661                        Entire condo    100-150
# 29662                  Entire rental unit    100-150
# 29663                        Entire condo     50-100
# 29664                  Entire rental unit     50-100
# 29665                Private room in home     50-100
# 29666         Private room in rental unit     50-100
# 29667         Private room in rental unit    100-150
# 29668                  Entire rental unit    100-150
# 29669                  Entire rental unit       200+
# 29670   Private room in bed and breakfast     50-100
# 29671                        Entire condo       200+
# 29672                        Entire condo    150-200
# 29673                  Entire rental unit    100-150
# 29674                  Entire rental unit    100-150
# 29675                        Entire condo     50-100
# 29676         Private room in rental unit     50-100
# 29677                  Entire rental unit     50-100
# 29678                  Entire rental unit     50-100
# 29679                  Entire rental unit    100-150
# 29680                  Entire rental unit       200+
# 29681                Private room in home     50-100
# 29682         Private room in rental unit     50-100
# 29683                         Entire home    100-150
# 29684                         Entire home    100-150
# 29685                        Entire condo     50-100
# 29686         Private room in rental unit     50-100
# 29687   Private room in bed and breakfast     50-100
# 29688                  Entire rental unit    100-150
# 29689                         Entire home     50-100
# 29690                  Entire rental unit     50-100
# 29691                  Entire rental unit    100-150
# 29692                  Entire rental unit    150-200
# 29693                               Other     50-100
# 29694                  Entire rental unit     50-100
# 29695                  Entire rental unit    100-150
# 29696                Entire vacation home       200+
# 29697                        Entire condo    100-150
# 29698   Private room in bed and breakfast    100-150
# 29699                  Entire rental unit       200+
# 29700                Entire vacation home       200+
# 29701                  Entire rental unit    100-150
# 29702                  Entire rental unit    100-150
# 29703                  Entire rental unit       200+
# 29704                        Entire condo    150-200
# 29705                        Entire condo    150-200
# 29706                  Entire rental unit     50-100
# 29707                        Entire condo    100-150
# 29708                  Entire rental unit    100-150
# 29709                  Entire rental unit    150-200
# 29710                        Entire condo    100-150
# 29711                  Entire rental unit       200+
# 29712                Private room in home     50-100
# 29713                  Entire rental unit     50-100
# 29714               Private room in condo     50-100
# 29715                  Entire rental unit    150-200
# 29716                  Entire rental unit    150-200
# 29717               Private room in condo     50-100
# 29718         Private room in rental unit    100-150
# 29719                  Entire rental unit       200+
# 29720         Private room in rental unit    100-150
# 29721          Shared room in rental unit     50-100
# 29722                         Entire home       200+
# 29723                         Entire home    150-200
# 29724                  Entire rental unit    150-200
# 29725                         Entire home    100-150
# 29726   Private room in bed and breakfast       200+
# 29727                  Entire rental unit       200+
# 29728                         Entire home       200+
# 29729                  Entire rental unit       200+
# 29730                         Entire home       200+
# 29731                  Entire rental unit    100-150
# 29732                  Entire rental unit       200+
# 29733   Private room in bed and breakfast       200+
# 29734                  Entire rental unit    150-200
# 29735                  Entire rental unit    100-150
# 29736                  Entire rental unit    100-150
# 29737         Private room in rental unit    100-150
# 29738         Private room in rental unit     50-100
# 29739                  Entire rental unit    150-200
# 29740                  Entire rental unit    100-150
# 29741                  Entire rental unit        NaN
# 29742                  Entire rental unit    150-200
# 29743                  Entire rental unit    150-200
# 29744                  Entire rental unit       200+
# 29745   Private room in bed and breakfast       200+
# 29746   Private room in bed and breakfast       200+
# 29747                  Entire rental unit     50-100
# 29748                  Entire rental unit    100-150
# 29749                  Entire rental unit       200+
# 29750                  Entire rental unit       200+
# 29751         Private room in rental unit     50-100
# 29752                  Entire rental unit     50-100
# 29753                         Entire home    100-150
# 29754                  Entire rental unit       200+
# 29755                  Entire rental unit     50-100
# 29756                  Entire rental unit     50-100
# 29757         Private room in rental unit     50-100
# 29758                  Entire rental unit       200+
# 29759                  Entire rental unit       200+
# 29760                  Entire rental unit     50-100
# 29761   Private room in bed and breakfast       200+
# 29762   Private room in bed and breakfast       200+
# 29763                        Entire condo    150-200
# 29764                  Entire rental unit       200+
# 29765                  Entire rental unit     50-100
# 29766         Private room in rental unit     50-100
# 29767         Private room in rental unit     50-100
# 29768                  Entire rental unit     50-100
# 29769                  Entire rental unit     50-100
# 29770                  Entire rental unit    100-150
# 29771                  Entire rental unit     50-100
# 29772                  Entire rental unit     50-100
# 29773                  Entire rental unit       200+
# 29774                  Entire rental unit       200+
# 29775                  Entire rental unit    150-200
# 29776                  Entire rental unit     50-100
# 29777                  Entire rental unit    100-150
# 29778                  Entire rental unit    100-150
# 29779                  Entire rental unit     50-100
# 29780                        Entire condo       200+
# 29781                  Entire rental unit    100-150
# 29782                Entire vacation home    100-150
# 29783                        Entire condo    100-150
# 29784                Private room in home    100-150
# 29785         Private room in rental unit    150-200
# 29786                  Entire rental unit    150-200
# 29787   Private room in bed and breakfast       200+
# 29788   Private room in bed and breakfast       200+
# 29789   Private room in bed and breakfast    100-150
# 29790   Private room in bed and breakfast    150-200
# 29791                  Entire rental unit    150-200
# 29792                  Entire rental unit    150-200
# 29793                  Entire rental unit    150-200
# 29794                  Entire rental unit       200+
# 29795                  Entire rental unit    150-200
# 29796                        Entire condo       200+
# 29797                  Entire rental unit       200+
# 29798                  Entire rental unit       200+
# 29799                         Entire home       200+
# 29800                  Entire rental unit       200+
# 29801                         Entire home     50-100
# 29802                  Entire rental unit    150-200
# 29803                  Entire rental unit     50-100
# 29804         Private room in rental unit    100-150
# 29805         Private room in rental unit    100-150
# 29806                  Entire rental unit    100-150
# 29807                        Entire condo    100-150
# 29808                  Entire rental unit    100-150
# 29809                        Entire condo       200+
# 29810         Private room in rental unit        <50
# 29811                         Entire home    100-150
# 29812                  Entire rental unit    150-200
# 29813                  Entire rental unit     50-100
# 29814         Private room in rental unit     50-100
# 29815                               Other     50-100
# 29816                               Other     50-100
# 29817                               Other     50-100
# 29818                  Entire rental unit    150-200
# 29819                  Entire rental unit       200+
# 29820                        Entire condo    100-150
# 29821                  Entire rental unit       200+
# 29822                  Entire rental unit     50-100
# 29823                  Entire rental unit    100-150
# 29824                         Entire home    150-200
# 29825                  Entire rental unit        NaN
# 29826                        Entire condo     50-100
# 29827                  Entire rental unit       200+
# 29828                  Entire rental unit     50-100
# 29829                  Entire rental unit    150-200
# 29830                  Entire rental unit       200+
# 29831                        Entire condo    100-150
# 29832                        Entire condo    100-150
# 29833                       Room in hotel        NaN
# 29834                               Other     50-100
# 29835                  Entire rental unit    150-200
# 29836                  Entire rental unit       200+
# 29837                  Entire rental unit    100-150
# 29838                  Entire rental unit    100-150
# 29839                  Entire rental unit     50-100
# 29840                  Entire rental unit    100-150
# 29841         Private room in rental unit        NaN
# 29842                  Entire rental unit       200+
# 29843                        Entire condo    100-150
# 29844                Private room in home     50-100
# 29845                  Entire rental unit       200+
# 29846                  Entire rental unit       200+
# 29847                  Entire rental unit    100-150
# 29848                        Entire condo    150-200
# 29849                        Entire condo       200+
# 29850                  Entire rental unit    100-150
# 29851                  Entire rental unit       200+
# 29852                  Entire rental unit     50-100
# 29853                  Entire rental unit       200+
# 29854         Private room in rental unit     50-100
# 29855                  Entire rental unit       200+
# 29856   Private room in bed and breakfast    150-200
# 29857                         Entire home       200+
# 29858   Private room in bed and breakfast    100-150
# 29859                  Entire rental unit    150-200
# 29860                  Entire rental unit    150-200
# 29861                  Entire rental unit       200+
# 29862                  Entire rental unit    100-150
# 29863                  Entire rental unit       200+
# 29864                  Entire rental unit        NaN
# 29865                  Entire rental unit       200+
# 29866                  Entire rental unit    100-150
# 29867                  Entire rental unit    100-150
# 29868         Private room in rental unit     50-100
# 29869         Private room in rental unit    100-150
# 29870                  Entire rental unit    150-200
# 29871   Private room in bed and breakfast     50-100
# 29872         Private room in rental unit     50-100
# 29873         Private room in rental unit     50-100
# 29874                         Entire home       200+
# 29875                        Entire condo       200+
# 29876         Private room in rental unit     50-100
# 29877                  Entire rental unit     50-100
# 29878                  Entire rental unit       200+
# 29879                        Entire condo    150-200
# 29880         Private room in rental unit    150-200
# 29881                  Entire rental unit    100-150
# 29882         Private room in rental unit    100-150
# 29883                  Entire rental unit     50-100
# 29884         Private room in rental unit     50-100
# 29885   Private room in bed and breakfast    100-150
# 29886                  Entire rental unit     50-100
# 29887                  Entire rental unit    100-150
# 29888                  Entire rental unit       200+
# 29889                  Entire rental unit       200+
# 29890                  Entire rental unit    150-200
# 29891                Entire vacation home       200+
# 29892                  Entire rental unit       200+
# 29893                  Entire rental unit       200+
# 29894                  Entire rental unit       200+
# 29895                  Entire rental unit    100-150
# 29896                  Entire rental unit     50-100
# 29897                Entire vacation home     50-100
# 29898                  Entire rental unit     50-100
# 29899                        Entire condo     50-100
# 29900                         Entire home    150-200
# 29901         Private room in rental unit        NaN
# 29902                        Entire condo        NaN
# 29903                        Entire condo    100-150
# 29904                  Entire rental unit     50-100
# 29905                  Entire rental unit       200+
# 29906                  Entire rental unit    100-150
# 29907                  Entire rental unit     50-100
# 29908                  Entire rental unit    100-150
# 29909                        Entire condo    150-200
# 29910                Entire vacation home       200+
# 29911                  Entire rental unit       200+
# 29912                  Entire rental unit     50-100
# 29913                  Entire rental unit    100-150
# 29914         Private room in rental unit    100-150
# 29915                  Entire rental unit     50-100
# 29916         Private room in rental unit     50-100
# 29917                  Entire rental unit    150-200
# 29918                  Entire rental unit    100-150
# 29919                  Entire rental unit       200+
# 29920                         Entire home     50-100
# 29921               Private room in condo     50-100
# 29922         Private room in rental unit     50-100
# 29923                Entire vacation home     50-100
# 29924                  Entire rental unit     50-100
# 29925                  Entire rental unit     50-100
# 29926         Private room in rental unit     50-100
# 29927   Private room in bed and breakfast       200+
# 29928                  Entire rental unit    100-150
# 29929                  Entire rental unit    150-200
# 29930                        Entire condo       200+
# 29931         Private room in rental unit    100-150
# 29932                  Entire rental unit    150-200
# 29933                Entire vacation home    150-200
# 29934         Private room in rental unit    100-150
# 29935                  Entire rental unit    150-200
# 29936         Private room in rental unit    100-150
# 29937                  Entire rental unit    100-150
# 29938                               Other       200+
# 29939                  Entire rental unit     50-100
# 29940                         Entire home    150-200
# 29941                  Entire rental unit       200+
# 29942                  Entire rental unit       200+
# 29943         Private room in rental unit     50-100
# 29944                  Entire rental unit       200+
# 29945                  Entire rental unit       200+
# 29946                  Entire rental unit    100-150
# 29947                  Entire rental unit       200+
# 29948                        Entire condo        NaN
# 29949                Entire vacation home     50-100
# 29950                        Entire condo    100-150
# 29951                  Entire rental unit     50-100
# 29952                  Entire rental unit    100-150
# 29953                  Entire rental unit    100-150
# 29954                  Entire rental unit    150-200
# 29955                  Entire rental unit    100-150
# 29956         Private room in rental unit    100-150
# 29957                  Entire rental unit    150-200
# 29958         Private room in rental unit    100-150
# 29959                  Entire rental unit    100-150
# 29960                Private room in home        <50
# 29961   Private room in bed and breakfast     50-100
# 29962                  Entire rental unit    100-150
# 29963                Entire vacation home    100-150
# 29964                  Entire rental unit    100-150
# ...
# 33760         Private room in rental unit     50-100
# 33761         Private room in rental unit    100-150
# 33762                         Entire home     50-100
# 33763                        Entire condo       200+
# 33764                         Entire home    100-150
# 33765                  Entire rental unit     50-100
# 33766                  Entire rental unit    150-200
# 33767                        Entire condo     50-100
# 33768                  Entire rental unit    150-200
# 33769   Private room in bed and breakfast       200+
# 33770                  Entire rental unit    150-200
# 33771   Private room in bed and breakfast       200+
# 33772         Private room in rental unit       200+
# 33773                  Entire rental unit     50-100
# 33774                  Entire rental unit     50-100
# 33775                  Entire rental unit       200+
# 33776                  Entire rental unit    100-150
# 33777                  Entire rental unit    100-150
# 33778   Private room in bed and breakfast     50-100
# 33779                  Entire rental unit       200+
# 33780                  Entire rental unit       200+
# 33781                  Entire rental unit    100-150
# 33782   Private room in bed and breakfast       200+
# 33783                  Entire rental unit     50-100
# 33784                  Entire rental unit       200+
# 33785                  Entire rental unit     50-100
# 33786                  Entire rental unit    100-150
# 33787                        Entire condo    150-200
# 33788                  Entire rental unit    150-200
# 33789                  Entire rental unit     50-100
# 33790                  Entire rental unit     50-100
# 33791                Private room in home        <50
# 33792         Private room in rental unit     50-100
# 33793                  Entire rental unit       200+
# 33794   Private room in bed and breakfast        <50
# 33795                  Entire rental unit    100-150
# 33796                  Entire rental unit    100-150
# 33797         Private room in rental unit     50-100
# 33798   Private room in bed and breakfast    150-200
# 33799                  Entire rental unit    100-150
# 33800                           Tiny home    100-150
# 33801                  Entire rental unit    100-150
# 33802                Private room in home     50-100
# 33803         Private room in rental unit    150-200
# 33804                  Entire rental unit       200+
# 33805                  Entire rental unit       200+
# 33806                  Entire rental unit       200+
# 33807                  Entire rental unit       200+
# 33808                  Entire rental unit       200+
# 33809                  Entire rental unit    150-200
# 33810                  Entire rental unit       200+
# 33811                  Entire rental unit       200+
# 33812                  Entire rental unit       200+
# 33813                  Entire rental unit       200+
# 33814                  Entire rental unit    100-150
# 33815                         Entire home     50-100
# 33816                  Entire rental unit    100-150
# 33817                  Entire rental unit    150-200
# 33818                  Entire rental unit       200+
# 33819                  Entire rental unit     50-100
# 33820                Private room in home     50-100
# 33821                        Entire condo    150-200
# 33822                Private room in home     50-100
# 33823                  Entire rental unit    100-150
# 33824                  Entire rental unit       200+
# 33825                        Entire condo       200+
# 33826                        Entire condo    150-200
# 33827   Private room in bed and breakfast     50-100
# 33828                  Entire rental unit    150-200
# 33829               Private room in condo     50-100
# 33830                         Entire loft     50-100
# 33831                  Entire rental unit     50-100
# 33832                        Entire condo    100-150
# 33833   Private room in bed and breakfast    100-150
# 33834                  Entire rental unit    100-150
# 33835   Private room in bed and breakfast     50-100
# 33836                         Entire home    150-200
# 33837                         Entire home       200+
# 33838         Private room in rental unit     50-100
# 33839                  Entire rental unit    150-200
# 33840           Entire serviced apartment    150-200
# 33841           Entire serviced apartment       200+
# 33842         Private room in rental unit     50-100
# 33843                Entire vacation home     50-100
# 33844                  Entire rental unit       200+
# 33845                  Entire rental unit       200+
# 33846         Private room in rental unit     50-100
# 33847                  Entire rental unit    100-150
# 33848                  Entire rental unit    150-200
# 33849                  Entire rental unit    150-200
# 33850         Private room in rental unit     50-100
# 33851               Private room in condo     50-100
# 33852           Entire serviced apartment       200+
# 33853                         Entire home     50-100
# 33854                  Entire rental unit       200+
# 33855                  Entire rental unit       200+
# 33856   Private room in bed and breakfast    100-150
# 33857         Private room in rental unit     50-100
# 33858         Private room in rental unit     50-100
# 33859                        Entire villa    150-200
# 33860                  Entire rental unit    100-150
# 33861                  Entire rental unit    100-150
# 33862               Private room in condo    100-150
# 33863               Private room in condo    100-150
# 33864         Private room in rental unit     50-100
# 33865         Private room in rental unit     50-100
# 33866                  Entire rental unit     50-100
# 33867                  Entire rental unit     50-100
# 33868                  Entire rental unit    100-150
# 33869                  Entire rental unit    100-150
# 33870         Private room in rental unit    100-150
# 33871                        Entire condo    100-150
# 33872   Private room in bed and breakfast    150-200
# 33873                  Entire rental unit     50-100
# 33874                  Entire rental unit     50-100
# 33875                  Entire rental unit    100-150
# 33876                  Entire rental unit       200+
# 33877                  Entire rental unit    100-150
# 33878         Private room in rental unit    100-150
# 33879                  Entire rental unit       200+
# 33880                  Entire rental unit     50-100
# 33881                  Entire rental unit       200+
# 33882                  Entire rental unit     50-100
# 33883                  Entire rental unit       200+
# 33884                  Entire rental unit    100-150
# 33885                  Entire rental unit     50-100
# 33886                        Entire condo    150-200
# 33887         Private room in rental unit     50-100
# 33888                  Entire rental unit    100-150
# 33889                  Entire rental unit       200+
# 33890                  Entire rental unit       200+
# 33891                  Entire rental unit     50-100
# 33892         Private room in rental unit    100-150
# 33893                  Entire rental unit       200+
# 33894                        Entire condo    100-150
# 33895                        Entire condo    100-150
# 33896         Private room in rental unit        <50
# 33897   Private room in bed and breakfast     50-100
# 33898                  Entire rental unit    100-150
# 33899                  Entire rental unit     50-100
# 33900                  Entire rental unit    100-150
# 33901                Private room in home     50-100
# 33902                  Entire rental unit    150-200
# 33903         Private room in rental unit    100-150
# 33904                  Entire rental unit    100-150
# 33905                  Entire rental unit     50-100
# 33906                           Tiny home     50-100
# 33907                  Entire rental unit       200+
# 33908                  Entire rental unit       200+
# 33909                         Entire home     50-100
# 33910                  Entire rental unit    100-150
# 33911                  Entire rental unit       200+
# 33912                  Entire rental unit     50-100
# 33913                        Entire condo       200+
# 33914                  Entire rental unit       200+
# 33915                  Entire rental unit     50-100
# 33916                  Entire rental unit       200+
# 33917                  Entire rental unit     50-100
# 33918                  Entire rental unit    150-200
# 33919                  Entire rental unit    150-200
# 33920                  Entire rental unit    100-150
# 33921                        Entire condo     50-100
# 33922                  Entire rental unit       200+
# 33923                           Tiny home     50-100
# 33924                  Entire rental unit     50-100
# 33925                         Entire home     50-100
# 33926                  Entire rental unit    150-200
# 33927                  Entire rental unit     50-100
# 33928                  Entire rental unit    100-150
# 33929                        Entire condo       200+
# 33930                        Entire condo     50-100
# 33931         Private room in rental unit     50-100
# 33932                  Entire rental unit    150-200
# 33933                  Entire rental unit     50-100
# 33934                         Entire home    100-150
# 33935                         Entire home     50-100
# 33936                  Entire rental unit    100-150
# 33937                  Entire rental unit    150-200
# 33938                  Entire rental unit    150-200
# 33939                  Entire rental unit       200+
# 33940                  Entire rental unit    150-200
# 33941                  Entire rental unit       200+
# 33942                Entire vacation home    100-150
# 33943                  Entire rental unit    100-150
# 33944         Private room in rental unit    100-150
# 33945                         Entire home       200+
# 33946         Private room in rental unit     50-100
# 33947                  Entire rental unit    100-150
# 33948               Private room in condo    100-150
# 33949                  Entire rental unit    100-150
# 33950               Private room in condo    100-150
# 33951                  Entire rental unit    100-150
# 33952                Private room in home     50-100
# 33953                        Entire condo       200+
# 33954         Private room in rental unit        <50
# 33955                         Entire home     50-100
# 33956                  Entire rental unit    100-150
# 33957                  Entire rental unit    100-150
# 33958                  Entire rental unit       200+
# 33959                  Entire rental unit        <50
# 33960                         Entire home     50-100
# 33961                  Entire rental unit    150-200
# 33962         Private room in rental unit     50-100
# 33963                  Entire rental unit       200+
# 33964         Private room in rental unit        <50
# 33965                        Entire condo    100-150
# 33966                  Entire rental unit    150-200
# 33967                  Entire rental unit     50-100
# 33968                  Entire rental unit     50-100
# 33969                  Entire rental unit     50-100
# 33970                  Entire rental unit       200+
# 33971                  Entire rental unit    100-150
# 33972                  Entire rental unit    100-150
# 33973                  Entire rental unit    150-200
# 33974                        Entire condo       200+
# 33975                  Entire rental unit     50-100
# 33976                  Entire rental unit    100-150
# 33977               Private room in condo     50-100
# 33978                  Entire rental unit     50-100
# 33979                  Entire rental unit       200+
# 33980                  Entire rental unit    100-150
# 33981                  Entire rental unit    150-200
# 33982                  Entire rental unit    100-150
# 33983                  Entire rental unit       200+
# 33984                  Entire rental unit     50-100
# 33985                  Entire rental unit    100-150
# 33986                  Entire rental unit    150-200
# 33987         Private room in rental unit    100-150
# 33988         Private room in rental unit    100-150
# 33989                  Entire rental unit    150-200
# 33990         Private room in rental unit    100-150
# 33991                Entire vacation home       200+
# 33992                        Entire condo    150-200
# 33993         Private room in rental unit     50-100
# 33994                  Entire rental unit    150-200
# 33995                  Entire rental unit    100-150
# 33996                  Entire rental unit    150-200
# 33997                  Entire rental unit     50-100
# 33998                         Entire home     50-100
# 33999                  Entire rental unit    100-150
# 34000                  Entire rental unit     50-100
# 34001                        Entire condo     50-100
# 34002                  Entire rental unit    100-150
# 34003                  Entire rental unit    100-150
# 34004                  Entire rental unit     50-100
# 34005                  Entire rental unit    100-150
# 34006                  Entire rental unit    100-150
# 34007   Private room in bed and breakfast       200+
# 34008                  Entire rental unit     50-100
# 34009                  Entire rental unit    100-150
# 34010                  Entire rental unit       200+
# 34011                  Entire rental unit       200+
# 34012         Private room in rental unit     50-100
# 34013         Private room in rental unit     50-100
# 34014                  Entire rental unit     50-100
# 34015                  Entire rental unit    100-150
# 34016                  Entire rental unit    150-200
# 34017                               Other     50-100
# 34018                        Entire condo     50-100
# 34019                  Entire rental unit    150-200
# 34020                         Entire home     50-100
# 34021                  Entire rental unit    100-150
# 34022                  Entire rental unit    150-200
# 34023                  Entire rental unit     50-100
# 34024                  Entire rental unit     50-100
# 34025                  Entire rental unit       200+
# 34026                  Entire rental unit     50-100
# 34027                  Entire rental unit       200+
# 34028                        Entire condo     50-100
# 34029                  Entire rental unit    100-150
# 34030                  Entire rental unit    150-200
# 34031                  Entire rental unit    100-150
# 34032                  Entire rental unit     50-100
# 34033                  Entire rental unit    150-200
# 34034                  Entire rental unit       200+
# 34035                  Entire rental unit       200+
# 34036         Private room in rental unit     50-100
# 34037                  Entire rental unit       200+
# 34038                  Entire rental unit     50-100
# 34039                  Entire rental unit       200+
# 34040                        Entire condo    150-200
# 34041                  Entire rental unit    100-150
# 34042                  Entire rental unit       200+
# 34043   Private room in bed and breakfast     50-100
# 34044                  Entire rental unit       200+
# 34045                  Entire rental unit    100-150
# 34046                  Entire rental unit    100-150
# 34047   Private room in bed and breakfast    100-150
# 34048                  Entire rental unit     50-100
# 34049                  Entire rental unit     50-100
# 34050                  Entire rental unit       200+
# 34051                  Entire rental unit    150-200
# 34052                               Other     50-100
# 34053                  Entire rental unit     50-100
# 34054                  Entire rental unit     50-100
# 34055         Private room in rental unit    100-150
# 34056                  Entire rental unit    150-200
# 34057                  Entire rental unit       200+
# 34058                        Entire condo     50-100
# 34059                  Entire rental unit     50-100
# 34060                  Entire rental unit       200+

# %% [markdown]
# Version with only catégories with more then 50 elements.

# %%
# Calculate % of appartement in each categorie for each property type
grouped = df_property_type_grouped.groupby(['property_type_grouped', 'price_bins'],observed=True).size().unstack(fill_value=0)
percentage = grouped.div(grouped.sum(axis=1), axis=0) * 100

# Show graph
percentage = percentage.fillna(0)  # Remplacer NaN par 0
percentage.plot(kind='bar', stacked=True, figsize=(12, 8))

plt.title('Percentage of appartement of each property type (that has more then 50 appartements) in each price range')
plt.xlabel('Property type')
plt.ylabel('Percentage (%)')
plt.legend(title='Price ranges', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Room type

# %%
# Calculate % of appartement in each categorie for each room type
grouped = df_analisis.groupby(['room_type', 'price_bins'],observed=True).size().unstack(fill_value=0)
percentage = grouped.div(grouped.sum(axis=1), axis=0) * 100

# Show graph
percentage = percentage.fillna(0)  # Remplacer NaN par 0
percentage.plot(kind='bar', stacked=True, figsize=(12, 8))

plt.title('Percentage of appartement for each room type in each price range')
plt.xlabel('Room type')
plt.ylabel('Percentage (%)')
plt.legend(title='Price ranges', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The type of room and type of property (which is a more detailed version of the first one) also seem correlated and will be useful data to train our model.

# %% [markdown]
# ##Valores Faltantes

# %% [markdown]
# ### NaNs

# %% [markdown]
# Percentaje de NaNs

# %%
filas_totales = df.shape[0]
print(df.isna().sum() / filas_totales * 100)
# Out:
# id                                0.000000
# host_id                           0.000000
# host_total_listings_count         0.000000
# neighbourhood_cleansed            0.000000
# neighbourhood_group_cleansed    100.000000
# latitude                          0.000000
# longitude                         0.000000
# property_type                     0.000000
# room_type                         0.000000
# accommodates                      0.000000
# bathrooms                        11.044890
# bathrooms_text                    0.135052
# bedrooms                          2.771498
# beds                             11.226916
# price                            11.053698
# minimum_nights                    0.000000
# maximum_nights                    0.000000
# review_scores_location           14.920290
# amenities_number                  0.000000
# dtype: float64

# %% [markdown]
# ### Otros tipos de valores faltantes

# %% [markdown]
# #### Caracter raro
# Vamos a analizar el dataset general
# Ici on verifie si on a pas d'autre truc qui sont pas des NaN mais qui nous embêtent aussi

# %%
tienen_caracter_raro = df.astype("str").eq("-").any()
print("Columnas con caracteres raros:")
tienen_caracter_raro
# Out:
# Columnas con caracteres raros:
# id                              False
# host_id                         False
# host_total_listings_count       False
# neighbourhood_cleansed          False
# neighbourhood_group_cleansed    False
# latitude                        False
# longitude                       False
# property_type                   False
# room_type                       False
# accommodates                    False
# bathrooms                       False
# bathrooms_text                  False
# bedrooms                        False
# beds                            False
# price                           False
# minimum_nights                  False
# maximum_nights                  False
# review_scores_location          False
# amenities_number                False
# dtype: bool

# %% [markdown]
# #### Valores imposibles
# We are checking for values >0

# %% [markdown]
# Columns with numerical values :

# %%
numeric_columns = df.select_dtypes(include=np.number).columns.tolist()
print(numeric_columns)
# Out:
# ['id', 'host_id', 'host_total_listings_count', 'neighbourhood_group_cleansed', 'latitude', 'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price', 'minimum_nights', 'maximum_nights', 'review_scores_location', 'amenities_number']

# %% [markdown]
# Checking if there exists values < 0

# %%
(df[numeric_columns] < 0).any().to_frame("Menor que 0 ?")
# Out:
#                               Menor que 0 ?
# id                                    False
# host_id                               False
# host_total_listings_count             False
# neighbourhood_group_cleansed          False
# latitude                              False
# longitude                             False
# accommodates                          False
# bathrooms                             False
# bedrooms                              False
# beds                                  False
# price                                 False
# minimum_nights                        False
# maximum_nights                        False
# review_scores_location                False
# amenities_number                      False

# %% [markdown]
# As we can see, we don't have below zero values.

# %% [markdown]
# #### Duplicados

# %% [markdown]
# Checking for duplicates

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, host_id, host_total_listings_count, neighbourhood_cleansed, neighbourhood_group_cleansed, latitude, longitude, property_type, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, price, minimum_nights, maximum_nights, review_scores_location, amenities_number]
# Index: []

# %% [markdown]
# We don't have any duplicates.

# %% [markdown]
# ### Taking care of NaN values

# %%
filas_totales = df.shape[0]
print(df.isna().sum() / filas_totales * 100)
# Out:
# id                                0.000000
# host_id                           0.000000
# host_total_listings_count         0.000000
# neighbourhood_cleansed            0.000000
# neighbourhood_group_cleansed    100.000000
# latitude                          0.000000
# longitude                         0.000000
# property_type                     0.000000
# room_type                         0.000000
# accommodates                      0.000000
# bathrooms                        11.044890
# bathrooms_text                    0.135052
# bedrooms                          2.771498
# beds                             11.226916
# price                            11.053698
# minimum_nights                    0.000000
# maximum_nights                    0.000000
# review_scores_location           14.920290
# amenities_number                  0.000000
# dtype: float64

# %% [markdown]
# Column being **deleted**
# - Neighbourhood_group_cleansed
#
# Column were NaN are being **replaced by average**
# - Review_scores_location
#
# Column were NaN are being **replaced thanks to an other column** :
# - Bathrooms with Bathrooms_text
#
# Columns were NaNs are **replaced with MICE** (Multivariate Imputation by Chained Equations)
# - Accomodates : number of people that can sleep in the appartment
# - Bathroom
# - Bedroom
# - Beds
#
#   -> These columns are being replaced with MICE because they are all linked with one an other thus the values we will find are going to be good.
#
# Columns were NaNs **won't be replaced**
# - price
#
#   -> Imputing the NaNs in the price columns would be creating a bias in our model as estimating the price is the point of our model. We will have to erase the 10% of the lines were we don't have the price in order to avoid this biais.

# %% [markdown]
# #### Deleting the column

# %%
df = df.drop('neighbourhood_group_cleansed', axis=1)

# %% [markdown]
# #### Replacing by average

# %%
df['review_scores_location'] = df['review_scores_location'].fillna(df['review_scores_location'].mean())

# %% [markdown]
# #### Replacing thanks to an other column

# %%
print(df['bathrooms_text'].unique())
# Out:
# ['1.5 baths' '1 bath' '2 baths' '1 private bath' '3 baths' '5 baths'
#  '6.5 baths' '4 baths' '2.5 baths' '1 shared bath' nan '3 shared baths'
#  '2 shared baths' '0 shared baths' '1.5 shared baths' 'Half-bath'
#  '4.5 baths' '0 baths' '3.5 baths' '5.5 baths' '2.5 shared baths'
#  '12.5 baths' '6 baths' '5 shared baths' '7 baths' '6 shared baths'
#  'Shared half-bath' '8 baths' '7.5 baths' '12 baths' '9.5 baths'
#  'Private half-bath' '21.5 baths' '4 shared baths' '10 shared baths'
#  '9 baths' '10 baths' '5.5 shared baths' '24 baths']

# %% [markdown]
# Creating a bathroom_number column with the data of bathroom text in a numerical form

# %%
import re

#Fonction to keep only the numerical value in bathrooms_text
def extract_bathroom_number(text):
  """
  Extracts the numerical part of a bathroom description string.

  Args:
    text: The bathroom description string (e.g., "1.5 baths", "1 bath").

  Returns:
    The numerical part of the description, or None if no number is found.
  """
  if not isinstance(text, str):
    return None

  match = re.search(r"(\d+(\.\d+)?)", text)
  if match:
    return float(match.group(1))
  else:
    return None

# Apply the function to the 'bathrooms_text' column
df['bathroom_number'] = df['bathrooms_text'].apply(extract_bathroom_number)

# Replace bathroom_number with 0.5 if bathroom text contains 'Half-bath', 'Shared half-bath', or 'Private half-bath'
df.loc[(df['bathrooms_text'].str.contains('Half-bath', na=False)) |
       (df['bathrooms_text'].str.contains('Shared half-bath', na=False)) |
       (df['bathrooms_text'].str.contains('Private half-bath', na=False)), 'bathroom_number'] = 0.5

# %% [markdown]
# Remplace the NaNs of bathrooms by the value in bathroom_number

# %%
df['bathrooms'] = df['bathrooms'].fillna(df['bathroom_number'])

# %% [markdown]
# Deleting bathrooms_text now that we don't need it anymore

# %%
df.drop(['bathrooms_text','bathroom_number'], axis="columns", inplace=True)

# %% [markdown]
# #### Replacing with Multivariate Imputation by Chained Equations.

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

columns_to_imput = ['accommodates', 'bathrooms', 'bedrooms', 'beds']
imput = IterativeImputer(max_iter=10, random_state=0)
df[columns_to_imput] = imput.fit_transform(df[columns_to_imput])

# %% [markdown]
# #### Deleting lines with NaNs in the price column

# %%
df.dropna(subset=['price'], inplace=True)

# %% [markdown]
# #### Checking if we don't have any NaNs anymore.

# %%
filas_totales = df.shape[0]
print(df.isna().sum() / filas_totales * 100)
# Out:
# id                           0.0
# host_id                      0.0
# host_total_listings_count    0.0
# neighbourhood_cleansed       0.0
# latitude                     0.0
# longitude                    0.0
# property_type                0.0
# room_type                    0.0
# accommodates                 0.0
# bathrooms                    0.0
# bedrooms                     0.0
# beds                         0.0
# price                        0.0
# minimum_nights               0.0
# maximum_nights               0.0
# review_scores_location       0.0
# amenities_number             0.0
# dtype: float64

# %% [markdown]
# ## Analisis valores atipicos (outliers)

# %% [markdown]
# ### Analisis univariado

# %% [markdown]
# #### Drawing Boxplots to get a gobal idea

# %%
# Grafico de cajas
groups = [
    ['latitude', 'longitude'],
    ['price'],
    ['minimum_nights', 'maximum_nights'],
    ['accommodates', 'bathrooms'],
    ['bedrooms', 'beds']
]

for group in groups:
    plt.figure(figsize=(15, 5))
    for i, col in enumerate(group, 1):
        plt.subplot(1, len(group), i)
        sns.boxplot(y=df[col])
        plt.title(col)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# We can already see with the graphs that most variable have a lot of values far from average.
#
# We are going to calculate the percentage of outliers if we just consider distance to average.

# %%
def detect_outliers_iqr(df):
    Q1 = np.percentile(df, 25)
    Q3 = np.percentile(df, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = np.where((df < lower_bound) | (df > upper_bound))
    return outliers

# %%
outliers = pd.DataFrame(columns=['variable', 'cant outliers', 'porcentaje'])

for col in df.select_dtypes(include='number').columns:
    outliers_idx = detect_outliers_iqr(df[col])[0]
    if len(outliers_idx) > 0:
        outliers = pd.concat([outliers, pd.DataFrame({'variable': [col], 'cant outliers': [len(outliers_idx)], 'porcentaje': [len(outliers_idx) / df.shape[0] * 100]})], ignore_index=True)

outliers.sort_values('porcentaje', ascending=False)
# Out:
# <ipython-input-109-58a3a4138504>:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   outliers = pd.concat([outliers, pd.DataFrame({'variable': [col], 'cant outliers': [len(outliers_idx)], 'porcentaje': [len(outliers_idx) / df.shape[0] * 100]})], ignore_index=True)
#                      variable cant outliers  porcentaje
# 9              maximum_nights          6563   21.662926
# 0   host_total_listings_count          3812   12.582519
# 1                    latitude          2827    9.331265
# 7                       price          2300    7.591761
# 2                   longitude          1792    5.914972
# 10     review_scores_location          1561    5.152495
# 4                   bathrooms          1519    5.013863
# 3                accommodates          1446    4.772907
# 5                    bedrooms           782    2.581199
# 8              minimum_nights           727    2.399657
# 6                        beds           420    1.386322
# 11           amenities_number           109    0.359783

# %% [markdown]
# We can see that some variables such as maximums_nights or the coordinates have many outliers.
# We are also going to continue our analisis by looking at the percentage of outliers using modified z-score.

# %% [markdown]
# #### Z-Score Modificado

# %% [markdown]
# Calculating the percentage of outliers with Z-score modificado

# %%
# Function to calculate the modified Z-score for a given column
def modified_z_score(column):
    # Calculate the median of the column
    median = np.median(column)
    # Calculate the MAD (Median Absolute Deviation)
    mad = np.median(np.abs(column - median))
    # Compute the modified Z-score
    z_mod = 0.6745 * (column - median) / mad
    return z_mod

# Function to calculate the percentage of outliers in each numeric column of a DataFrame
def calculate_outliers_percentage(df):
    # Dictionary to store the percentage of outliers for each column
    outliers_percentage = {}

    # Iterate over each numeric column in the DataFrame
    for col in df.select_dtypes(include=[np.number]):
        # Apply the modified Z-score function to the column (ignoring NaN values)
        z_scores = modified_z_score(df[col].dropna())

        # Identify outliers where the absolute modified Z-score is greater than 3.5
        outliers = np.abs(z_scores) > 3.5

        # Calculate the percentage of outliers and store it in the dictionary
        outliers_percentage[col] = np.sum(outliers) / len(df[col].dropna()) * 100

    return outliers_percentage

# Calculate the percentage of outliers for each column
outliers_percent = calculate_outliers_percentage(df)

# Display the percentage of outliers for each column
for col, percent in outliers_percent.items():
    print(f"{col}: {percent:.2f}% of outliers")
# Out:
# id: 0.00% of outliers
# host_id: 0.00% of outliers
# host_total_listings_count: 18.46% of outliers
# latitude: 7.03% of outliers
# longitude: 4.50% of outliers
# accommodates: 0.28% of outliers
# bathrooms: 25.81% of outliers
# bedrooms: 37.99% of outliers
# beds: 0.82% of outliers
# price: 6.17% of outliers
# minimum_nights: 1.64% of outliers
# maximum_nights: 0.00% of outliers
# review_scores_location: 3.36% of outliers
# amenities_number: 0.04% of outliers

# %% [markdown]
# Using the modificated Z-score we have an even bigger amount of outliers in the variables bathrooms and bedrooms.

# %% [markdown]
# Let's look at what values of bedrooms and bathrooms are considered outliers

# %%
# Function to identify outliers in a DataFrame column using modified Z-score
def identify_outliers(df, column_name):
    z_scores = modified_z_score(df[column_name])
    outliers = df[np.abs(z_scores) > 3.5]
    return outliers

# Identify outliers in 'bathrooms' and 'bedrooms'
outliers_bathrooms = identify_outliers(df, 'bathrooms')
outliers_bedrooms = identify_outliers(df, 'bedrooms')

# Display the different values of outliers in 'bathrooms'
print("Different values of outliers in 'bathrooms':")
print(outliers_bathrooms['bathrooms'].unique())

# Display the different values of outliers in 'bedrooms'
print("\nDifferent values of outliers in 'bedrooms':")
print(outliers_bedrooms['bedrooms'].unique())
# Out:
# Different values of outliers in 'bathrooms':
# [ 1.5         2.          3.          5.          6.5         4.
#   2.5         0.94628503  0.          0.5         4.5         6.
#   3.5         5.5        12.5         7.          8.          7.5
#  12.          9.5        21.5        10.          9.          1.01759933]
#
# Different values of outliers in 'bedrooms':
# [ 2.          3.          0.          4.          5.          6.
#   0.93908751 12.         15.          7.         10.          8.
#   9.         21.         13.          1.51140735  1.1588328   1.22524743
#  17.         20.          0.82921486  1.35807669  1.29166206  0.33370787]

# %% [markdown]
# It seems that all values different then 1 are considered as outliers

# %%
percentage_bathrooms_1 = (df['bathrooms'] == 1).mean() * 100
percentage_bedrooms_1 = (df['bedrooms'] == 1).mean() * 100

print(f"Percentage of lines where bathrooms = 1 : {percentage_bathrooms_1:.2f}%")
print(f"Percentage of lines where bedrooms = 1  : {percentage_bedrooms_1:.2f}%")
# Out:
# Percentage of lines where bathrooms = 1 : 74.19%
# Percentage of lines where bedrooms = 1  : 62.01%

# %% [markdown]
# Because of the large number of appartment with only one bathroom/bedroom with the modificated z-score all values other then 1 are considered outliers.
#
# Deleting those "outliers" would be a considerable data loss and if the only possible value is one it does not participate in our model.
# We could thus use the quartil method to deal with outliers for these categories and modificated z-score to deal with outliers for the other categories.

# %% [markdown]
# ### Analisis multivariado

# %% [markdown]
# #### Distance de mahalanobis

# %%
columns_mahalanobis = ['latitude', 'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price', 'minimum_nights', 'maximum_nights', 'amenities_number']
df_mahalanobis = df[columns_mahalanobis]

# Calculate the covariance matrix of the numeric columns
cov_matrix = np.cov(df_mahalanobis.values, rowvar=False)

# Calculate the inverse of the covariance matrix
inv_cov_matrix = np.linalg.inv(cov_matrix)

# Calculate the mean of the numeric columns
mean_values = df_mahalanobis.mean(axis=0).values

# Function to calculate Mahalanobis distance for a given row
def mahalanobis_distance(row, mean, inv_cov_matrix):
    diff = row - mean
    return np.sqrt(np.dot(np.dot(diff, inv_cov_matrix), diff.T))

# Appling the function to each row and directly filter rows with mahalanobis > 7
mahalanobis_greater_than_7 = df_mahalanobis.apply(
    lambda row: mahalanobis_distance(row.values, mean_values, inv_cov_matrix) > 7,
    axis=1
)

# Number of lines where Mahalanobis > 7
num_lines_mahalanobis_sup_7 = mahalanobis_greater_than_7.sum()

# Percentage of lines where Mahalanobis > 7
percentage_mahalanobis_sup_7 = (num_lines_mahalanobis_sup_7 / len(df_mahalanobis)) * 100

print(f"\nPercentage of lines with Mahalanobis > 7: {percentage_mahalanobis_sup_7:.2f}%")
# Out:
# Percentage of lines with Mahalanobis > 7: 1.43%

# %% [markdown]
# Using the mahalanobis metod with all the concerned columns, we find very few outliers. We are choosing to use the univariable analisis to select the outliers we have to do something about but it would be interesting to see if we get better results by using the multivariable analisis.

# %% [markdown]
# ### Dealing with the spotted outliers

# %% [markdown]
# Replacing Bathrooms and Bedrooms outliers by the median of each variable.

# %%
def replace_outliers_with_median(df, column):
  Q1 = df[column].quantile(0.25)
  Q3 = df[column].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR

  median_value = df[column].median()
  df.loc[(df[column] < lower_bound) | (df[column] > upper_bound), column] = median_value

  return df


# Replace outliers for 'bathrooms' and 'bedrooms' with the median
df = replace_outliers_with_median(df, 'bathrooms')
df = replace_outliers_with_median(df, 'bedrooms')

# %% [markdown]
# For the other columns will be using the modified z-score methode to deal with outliers.

# %% [markdown]
# I tried deleting outliers or imputing them with the average value. I got significantly beter result deleting the outliers than imputing then, thus I left the version were they are being deleted.
#
# Results for linear regression when deleting outliers :
#
# ![image.png](data:image/png;base64,...)
#
# Resulat for XGBoost when deleting outliers :
#
# ![image.png](data:image/png;base64,...)
#
# Resulat for linar regression when imputing outliers :
#
# ![image.png](data:image/png;base64,...)
#
# Resulat for XGBoosst when imputing outliers :
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Version remplacing outliers (the call to the function is put as a comment # because it is not the version that we chose to keep.

# %%
import numpy as np

def modified_z_score(data):
    # Calculate the modified Z-score
    median = np.median(data)
    mad = np.median(np.abs(data - median))  # Median Absolute Deviation
    return 0.6745 * (data - median) / mad

def replace_outliers_with_median(df):
    df_selected = df.drop(['bedrooms', 'bathrooms'], axis=1)

    for col in df_selected.select_dtypes(include=[np.number]):
        z_scores = modified_z_score(df[col])

        outliers = np.abs(z_scores) > 3.5 #Rule of gold

        # Replace outliers with the median value of the column
        median_value = df[col].median()
        df.loc[outliers, col] = median_value

    return df

#df = replace_outliers_with_median(df)

# %% [markdown]
# Version deleting outliers

# %%
def remove_outliers(df):
    df_cleaned = df.copy()
    df_selected = df.drop(['bedrooms', 'bathrooms'], axis=1)
    for col in df_selected.select_dtypes(include=[np.number]):
        z_scores = modified_z_score(df_cleaned[col])

        outliers = np.abs(z_scores) > 3.5 #Rule of gold

        df_cleaned = df_cleaned.loc[~outliers]

    return df_cleaned

df_cleaned = remove_outliers(df)

print(f"Number of lines before deleting : {df.shape[0]}")
print(f"Number of lines after : {df_cleaned.shape[0]}")

df = df_cleaned.copy()
# Out:
# Number of lines before deleting : 30296
# Number of lines after : 16088

# %% [markdown]
# ## Transformacion de variables

# %% [markdown]
# Columns for which we are doing a min-max transformation : numerical columns
# - price
# - accomodates
# - bathrooms
# - bedrooms
# - beds
# - minimum nights
# - maximumm nigths
# - amenities
# - host_total_listings_count
# - review_scores_location
#
# Columns we are categorising : numerical columns with non-linear relationship with price
# - latitude
# - longitude
#
# Column in which we are grouping into biger categories
# - property type
#
# Columns to which we are applying OneHotEncoding : not numerical columns
# - neighbourhood
# - property type
# - room type
# - latitude_bin (latitude after being put in a categorie)
# - longitude_bin
#
# We chose to use OneHotEncoding even though some of the variables we are applying it to have a lot of different values possible because it avoid implying an order between categories.

# %% [markdown]
# ###Grouping into bigger categories

# %% [markdown]
# Printing the number of elements in each category to choose how to group them

# %%
property_type_counts = df_analisis['property_type'].value_counts()
print(property_type_counts)
# Out:
# property_type
# Entire rental unit                    16230
# Entire condo                           5610
# Private room in rental unit            3702
# Private room in bed and breakfast      1998
# Private room in condo                  1146
# Entire home                             990
# Entire vacation home                    964
# Entire loft                             484
# Room in boutique hotel                  376
# Private room in serviced apartment      340
# Private room in home                    307
# Room in hotel                           251
# Entire serviced apartment               249
# Room in bed and breakfast               241
# Entire villa                            127
# Private room in vacation home           102
# Private room in guesthouse               95
# Tiny home                                88
# Shared room in rental unit               76
# Room in serviced apartment               71
# Private room in villa                    68
# Private room in guest suite              61
# Room in aparthotel                       55
# Private room                             46
# Entire guest suite                       40
# Entire townhouse                         29
# Room in hostel                           27
# Private room in hostel                   23
# Shared room in hostel                    21
# Shared room in home                      20
# Private room in loft                     18
# Private room in casa particular          17
# Entire place                             16
# Entire guesthouse                        15
# Shared room in bed and breakfast         13
# Private room in townhouse                11
# Private room in tiny home                11
# Casa particular                          11
# Entire bed and breakfast                  9
# Shared room in hotel                      7
# Shared room in condo                      7
# Private room in nature lodge              7
# Entire cabin                              7
# Entire cottage                            6
# Shared room in guesthouse                 6
# Private room in farm stay                 5
# Farm stay                                 5
# Private room in castle                    5
# Camper/RV                                 4
# Dome                                      4
# Tower                                     4
# Boat                                      4
# Entire chalet                             3
# Private room in cottage                   3
# Entire home/apt                           3
# Entire bungalow                           3
# Private room in tower                     2
# Castle                                    2
# Private room in boat                      2
# Shared room in tent                       2
# Shared room in island                     1
# Shared room in townhouse                  1
# Private room in bungalow                  1
# Windmill                                  1
# Private room in minsu                     1
# Private room in pension                   1
# Campsite                                  1
# Shared room in boat                       1
# Private room in cabin                     1
# Cave                                      1
# Shared room in loft                       1
# Houseboat                                 1
# Name: count, dtype: int64

# %% [markdown]
# Grouping into categories in order to have at least 90 elements in each so the the category actualy means someting about the price.

# %%
df.loc[df['property_type'].str.contains('Shared room', na=False), 'property_type'] = 'Shared room'

# %%
# Count the number of lines with each possible value for property type
property_type_counts = df['property_type'].value_counts()

# Iterate over each property type
for property_type in property_type_counts.index:
  # Check if the property type contains 'Private room' and has less than 100 elements
  if 'Private room' in property_type and property_type_counts[property_type] < 100:
    # Change the property type to 'Private room' for all lines with this property type
    df.loc[df_analisis['property_type'] == property_type, 'property_type'] = 'Private room'

# %%
df.loc[df['property_type'].str.contains('Room', na=False), 'property_type'] = 'Room'

# %%
# Iterate over each property type
for property_type in property_type_counts.index:
  if 'Entire' in property_type and property_type_counts[property_type] < 120:
    df.loc[df_analisis['property_type'] == property_type, 'property_type'] = 'Entire place'

# %%
# Iterate over each property type
for property_type in property_type_counts.index:
  if property_type_counts[property_type] < 90:
    df.loc[df['property_type'] == property_type, 'property_type'] = 'Other'

# %% [markdown]
# Our new regrouped categories

# %%
property_type_counts = df['property_type'].value_counts()
print(property_type_counts)
# Out:
# property_type
# Entire rental unit                    7657
# Entire condo                          3096
# Private room in rental unit           1762
# Private room in bed and breakfast      890
# Private room in condo                  608
# Entire vacation home                   600
# Other                                  422
# Entire home                            376
# Entire loft                            250
# Room                                   208
# Private room in home                   113
# Private room in serviced apartment     106
# Name: count, dtype: int64

# %% [markdown]
# ### Creating categories (with bins)

# %%
def putting_into_categories(df, target, bins=8):
    numeric_columns = ['latitude','longitude']
    for column in numeric_columns:
        df[f'{column}_bin'] = pd.qcut(df[column], q=bins, duplicates='drop',labels=False)

putting_into_categories(df, target='price')

# %%
df.head()
# Out:
#       id  host_id  host_total_listings_count neighbourhood_cleansed  \
# 1   3079     3504                         11       I Centro Storico
# 2  11834    44552                          2       I Centro Storico
# 4  19965    75450                          9       I Centro Storico
# 5  50333   230736                          4       I Centro Storico
# 6  50471   231637                          4        XII Monte Verde
#
#     latitude  longitude       property_type        room_type  accommodates  \
# 1  41.895000  12.491170  Entire rental unit  Entire home/apt           4.0
# 2  41.895447  12.491181  Entire rental unit  Entire home/apt           2.0
# 4  41.907300  12.453490  Entire rental unit  Entire home/apt           5.0
# 5  41.913210  12.454820         Entire loft  Entire home/apt           3.0
# 6  41.882000  12.467300  Entire rental unit  Entire home/apt           3.0
#
#    bathrooms  bedrooms  beds  price  minimum_nights  maximum_nights  \
# 1        1.0       1.0   1.0  140.0               7             180
# 2        1.0       1.0   1.0  110.0               2              28
# 4        1.0       2.0   3.0  168.0               3             365
# 5        2.0       1.0   1.0  125.0               4               9
# 6        1.0       1.0   4.0  151.0               1               9
#
#    review_scores_location  amenities_number  latitude_bin  longitude_bin
# 1                    4.81                26             3              4
# 2                    4.99                50             3              4
# 4                    4.89                49             6              1
# 5                    4.79                40             7              1
# 6                    4.79                46             1              2

# %% [markdown]
# ###One Hot Encoding

# %%
df = pd.get_dummies(df, columns=["room_type","property_type","neighbourhood_cleansed","latitude_bin","longitude_bin"],drop_first=True)
display(df.head(2))
# Out:
#       id  host_id  host_total_listings_count   latitude  longitude  \
# 1   3079     3504                         11  41.895000  12.491170
# 2  11834    44552                          2  41.895447  12.491181
#
#    accommodates  bathrooms  bedrooms  beds  price  ...  latitude_bin_5  \
# 1           4.0        1.0       1.0   1.0  140.0  ...           False
# 2           2.0        1.0       1.0   1.0  110.0  ...           False
#
#    latitude_bin_6  latitude_bin_7  longitude_bin_1  longitude_bin_2  \
# 1           False           False            False            False
# 2           False           False            False            False
#
#    longitude_bin_3  longitude_bin_4  longitude_bin_5  longitude_bin_6  \
# 1            False             True            False            False
# 2            False             True            False            False
#
#    longitude_bin_7
# 1            False
# 2            False
#
# [2 rows x 55 columns]

# %% [markdown]
# ### Min-max transformation

# %%
columns_minmax_transformation = ['price', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'minimum_nights', 'amenities_number','host_total_listings_count','review_scores_location']
scaler = MinMaxScaler()

for column in columns_minmax_transformation:
    df[column + '_minmax'] = scaler.fit_transform(df[[column]])

# %% [markdown]
# ### Result of data transformation

# %%
df.head()
# Out:
#       id  host_id  host_total_listings_count   latitude  longitude  \
# 1   3079     3504                         11  41.895000  12.491170
# 2  11834    44552                          2  41.895447  12.491181
# 4  19965    75450                          9  41.907300  12.453490
# 5  50333   230736                          4  41.913210  12.454820
# 6  50471   231637                          4  41.882000  12.467300
#
#    accommodates  bathrooms  bedrooms  beds  price  ...  longitude_bin_7  \
# 1           4.0        1.0       1.0   1.0  140.0  ...            False
# 2           2.0        1.0       1.0   1.0  110.0  ...            False
# 4           5.0        1.0       2.0   3.0  168.0  ...            False
# 5           3.0        2.0       1.0   1.0  125.0  ...            False
# 6           3.0        1.0       1.0   4.0  151.0  ...            False
#
#    price_minmax  accommodates_minmax  bathrooms_minmax  bedrooms_minmax  \
# 1      0.346457             0.230769          0.333333         0.333333
# 2      0.267717             0.076923          0.333333         0.333333
# 4      0.419948             0.307692          0.333333         0.666667
# 5      0.307087             0.153846          1.000000         0.333333
# 6      0.375328             0.153846          0.333333         0.333333
#
#    beds_minmax  minimum_nights_minmax  amenities_number_minmax  \
# 1     0.142857               1.000000                 0.294118
# 2     0.142857               0.166667                 0.576471
# 4     0.428571               0.333333                 0.564706
# 5     0.142857               0.500000                 0.458824
# 6     0.571429               0.000000                 0.529412
#
#    host_total_listings_count_minmax  review_scores_location_minmax
# 1                          0.833333                       0.797872
# 2                          0.083333                       0.989362
# 4                          0.666667                       0.882979
# 5                          0.250000                       0.776596
# 6                          0.250000                       0.776596
#
# [5 rows x 64 columns]

# %%
df.columns
# Out:
# Index(['id', 'host_id', 'host_total_listings_count', 'latitude', 'longitude',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price',
#        'minimum_nights', 'maximum_nights', 'review_scores_location',
#        'amenities_number', 'room_type_Hotel room', 'room_type_Private room',
#        'room_type_Shared room', 'property_type_Entire home',
#        'property_type_Entire loft', 'property_type_Entire rental unit',
#        'property_type_Entire vacation home', 'property_type_Other',
#        'property_type_Private room in bed and breakfast',
#        'property_type_Private room in condo',
#        'property_type_Private room in home',
#        'property_type_Private room in rental unit',
#        'property_type_Private room in serviced apartment',
#        'property_type_Room', 'neighbourhood_cleansed_II Parioli/Nomentano',
#        'neighbourhood_cleansed_III Monte Sacro',
#        'neighbourhood_cleansed_IV Tiburtina', 'neighbourhood_cleansed_IX Eur',
#        'neighbourhood_cleansed_V Prenestino/Centocelle',
#        'neighbourhood_cleansed_VI Roma delle Torri',
#        'neighbourhood_cleansed_VII San Giovanni/Cinecittà',
#        'neighbourhood_cleansed_VIII Appia Antica',
#        'neighbourhood_cleansed_XI Arvalia/Portuense',
#        'neighbourhood_cleansed_XII Monte Verde',
#        'neighbourhood_cleansed_XIII Aurelia',
#        'neighbourhood_cleansed_XIV Monte Mario',
#        'neighbourhood_cleansed_XV Cassia/Flaminia', 'latitude_bin_1',
#        'latitude_bin_2', 'latitude_bin_3', 'latitude_bin_4', 'latitude_bin_5',
#        'latitude_bin_6', 'latitude_bin_7', 'longitude_bin_1',
#        'longitude_bin_2', 'longitude_bin_3', 'longitude_bin_4',
#        'longitude_bin_5', 'longitude_bin_6', 'longitude_bin_7', 'price_minmax',
#        'accommodates_minmax', 'bathrooms_minmax', 'bedrooms_minmax',
#        'beds_minmax', 'minimum_nights_minmax', 'amenities_number_minmax',
#        'host_total_listings_count_minmax', 'review_scores_location_minmax'],
#       dtype='object')

# %% [markdown]
# # Entrenamiento y Predicción

# %% [markdown]
# ##Modelo 1 : Regresión lineal

# %% [markdown]
# Printing the new correlation matrix again now that we cleaned the data.

# %%
import matplotlib.pyplot as plt
correlation_matrix = df[['accommodates', 'bathrooms',
       'bedrooms', 'beds', 'price', 'minimum_nights', 'maximum_nights',
       'amenities_number','host_total_listings_count','review_scores_location']].corr()
plt.figure(figsize=(15, 15))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# According to the correlation matrix some of the variable have a very little correlated with the price (minimum_nights for example). But I tried to make the linear regression without it and the result was less good.
#
# We also have some variables that are very correlated between each other (accomodate, bedroom, bathroom, bed) I tried to only keep some of the but once again the result was less good then with keeping all of them.
#
# Thus all of the variables from the above correlation matrix were kept in the models.

# %% [markdown]
# #### Building Linear Regression model

# %%
#Creo un regresor lineal
modelo_lineal_multiple = LinearRegression()

#Doy el formato adecuado a las variables dependiente e independiente
caracteristicas=df[[
       'room_type_Hotel room', 'room_type_Private room',
       'room_type_Shared room', 'property_type_Entire home',
       'property_type_Entire loft', 'property_type_Entire rental unit',
       'property_type_Entire vacation home', 'property_type_Other',
       'property_type_Private room in bed and breakfast',
       'property_type_Private room in condo',
       'property_type_Private room in home',
       'property_type_Private room in rental unit',
       'property_type_Private room in serviced apartment',
       'property_type_Room', 'neighbourhood_cleansed_II Parioli/Nomentano',
       'neighbourhood_cleansed_III Monte Sacro',
       'neighbourhood_cleansed_IV Tiburtina', 'neighbourhood_cleansed_IX Eur',
       'neighbourhood_cleansed_V Prenestino/Centocelle',
       'neighbourhood_cleansed_VI Roma delle Torri',
       'neighbourhood_cleansed_VII San Giovanni/Cinecittà',
       'neighbourhood_cleansed_VIII Appia Antica',
       'neighbourhood_cleansed_XI Arvalia/Portuense',
       'neighbourhood_cleansed_XII Monte Verde',
       'neighbourhood_cleansed_XIII Aurelia',
       'neighbourhood_cleansed_XIV Monte Mario',
       'neighbourhood_cleansed_XV Cassia/Flaminia',
       'latitude_bin_1', 'latitude_bin_2',
       'latitude_bin_3', 'latitude_bin_4', 'latitude_bin_5',
       'latitude_bin_6', 'latitude_bin_7', 'longitude_bin_1',
       'longitude_bin_2', 'longitude_bin_3', 'longitude_bin_4',
       'longitude_bin_5', 'longitude_bin_6', 'longitude_bin_7',
       'accommodates_minmax', 'bathrooms_minmax',
       'bedrooms_minmax', 'beds_minmax', 'minimum_nights_minmax',
       'amenities_number_minmax', 'host_total_listings_count_minmax',
       'review_scores_location_minmax']]
price=df['price'].values.reshape(-1, 1)

#Division del conjunto 80-20%
caracteristicas_train, caracteristicas_test, price_train, price_test = train_test_split(caracteristicas, price, test_size=0.2, random_state=42)

#Ajusto el modelo
modelo_lineal_multiple.fit(caracteristicas_train ,price_train)

# Coeficientes estimados
coeficientes = modelo_lineal_multiple.coef_[0]
intercepto = round(modelo_lineal_multiple.intercept_[0], 2)

# Muestro el modelo
print(f"El modelo lineal multiple ajustado es :")

for i, nombre_columna in enumerate(caracteristicas.columns):
    coeficiente = round(coeficientes[i], 2)
    print(f"{coeficiente} * {nombre_columna}")

print(f"+ {intercepto}")
# Out:
# El modelo lineal multiple ajustado es :
# -47.28 * room_type_Hotel room
# -28.2 * room_type_Private room
# -79.56 * room_type_Shared room
# 8.88 * property_type_Entire home
# -1.74 * property_type_Entire loft
# -0.96 * property_type_Entire rental unit
# 0.97 * property_type_Entire vacation home
# 11.77 * property_type_Other
# 34.91 * property_type_Private room in bed and breakfast
# 6.0 * property_type_Private room in condo
# 12.66 * property_type_Private room in home
# 12.76 * property_type_Private room in rental unit
# 30.79 * property_type_Private room in serviced apartment
# 64.78 * property_type_Room
# -19.65 * neighbourhood_cleansed_II Parioli/Nomentano
# -26.68 * neighbourhood_cleansed_III Monte Sacro
# -25.98 * neighbourhood_cleansed_IV Tiburtina
# -14.66 * neighbourhood_cleansed_IX Eur
# -24.1 * neighbourhood_cleansed_V Prenestino/Centocelle
# -23.34 * neighbourhood_cleansed_VI Roma delle Torri
# -5.61 * neighbourhood_cleansed_VII San Giovanni/Cinecittà
# -34.6 * neighbourhood_cleansed_VIII Appia Antica
# -18.77 * neighbourhood_cleansed_XI Arvalia/Portuense
# -4.67 * neighbourhood_cleansed_XII Monte Verde
# -11.77 * neighbourhood_cleansed_XIII Aurelia
# -16.91 * neighbourhood_cleansed_XIV Monte Mario
# -32.43 * neighbourhood_cleansed_XV Cassia/Flaminia
# 8.28 * latitude_bin_1
# 24.13 * latitude_bin_2
# 31.49 * latitude_bin_3
# 35.53 * latitude_bin_4
# 42.62 * latitude_bin_5
# 32.39 * latitude_bin_6
# 23.48 * latitude_bin_7
# 19.48 * longitude_bin_1
# 36.18 * longitude_bin_2
# 52.24 * longitude_bin_3
# 56.76 * longitude_bin_4
# 23.3 * longitude_bin_5
# 15.2 * longitude_bin_6
# 6.2 * longitude_bin_7
# 163.13 * accommodates_minmax
# 24.94 * bathrooms_minmax
# 50.77 * bedrooms_minmax
# -6.87 * beds_minmax
# -23.34 * minimum_nights_minmax
# 10.11 * amenities_number_minmax
# 18.97 * host_total_listings_count_minmax
# 38.87 * review_scores_location_minmax
# + 13.42

# %% [markdown]
# #### Results from train and test

# %%
#Train
price_pred_train=modelo_lineal_multiple.predict(caracteristicas_train)

# Result
mse_train = metrics.mean_squared_error(price_train, price_pred_train)
rmse_train = np.sqrt(mse_train)
r2_train = metrics.r2_score(price_train, price_pred_train)

print("Train :")
print(f"Mean Squared Error: {mse_train}")
print(f"Root Mean Squared Error: {rmse_train}")
print(f"R² Score: {r2_train}")

#Test
#Prediccion sobre casos nuevos con mis modelos ya entrenados
price_pred_test = modelo_lineal_multiple.predict(caracteristicas_test)

# Result
mse_test = metrics.mean_squared_error(price_test, price_pred_test)
rmse_test = np.sqrt(mse_test)
r2_test = metrics.r2_score(price_test, price_pred_test)

print("Test :")
print(f"Mean Squared Error: {mse_test}")
print(f"Root Mean Squared Error: {rmse_test}")
print(f"R² Score: {r2_test}")
# Out:
# Train :
# Mean Squared Error: 2563.313475535611
# Root Mean Squared Error: 50.62917612933881
# R² Score: 0.4889742224797212
# Test :
# Mean Squared Error: 2476.5187846018425
# Root Mean Squared Error: 49.7646338738852
# R² Score: 0.5151255346538651

# %% [markdown]
# ####Signification of diferent metrics
# - The value of rmse is the average distance between the real and the predicted price.
#
# - The value of mse is rmse².
# The lower rmse and mse we get, the better.
#
# - R² is the proportion of the variability of the price that can be explained by the features. The closest it is to 1 the better the model explains the variability.
#
# #### Result analisis :
# - Our value of R² is about 0.5, which means our model explains 50% of the variance in the price.
#
# - The rmse is lower in the tests then on the training, which is good because it means our model isn't overfitting.
#
# - The standard deviation for the price is 71 (see result of the code below), thus an RMSE of 50 is good even though it could propably be improved by optimisating the model more.

# %%
std_price = df['price'].std()
print(f"Standard deviation for the price : {std_price}")
# Out:
# Standard deviation for the price : 71.01971430494407

# %% [markdown]
# Version using crossed validation

# %%
caracteristicas_train, caracteristicas_test, price_train, price_test = train_test_split(
    caracteristicas, price, test_size=0.3, random_state=42)

model_linear = LinearRegression()

# Cross validation (5-folds)
cv_scores_mse = cross_val_score(model_linear, caracteristicas_train, price_train, cv=5, scoring='neg_mean_squared_error')
cv_scores_rmse = np.sqrt(-cv_scores_mse)

# Results
print("Cross-validation (training set) :")
print(f"Mean RMSE (5-folds): {np.mean(cv_scores_rmse):.2f}")
print(f"Standard deviation of RMSE (5-folds): {np.std(cv_scores_rmse):.2f}")
# Out:
# Cross-validation (training set) :
# Mean RMSE (5-folds): 50.84
# Standard deviation of RMSE (5-folds): 0.67

# %% [markdown]
# We chose 5 folds as the dataset is large so it seems sufficent.
#
# We find a mean rmse similar to the rmse we found without crossvalidation, and a small standard deviation which indicate the model's stability.

# %% [markdown]
# ## Modelo 2 : XGBoost

# %% [markdown]
# #### XGBoost testing different hyperparameters
# - n_estimators : total number of boosting iterations (trees)
# - max_depth : maximum depth of each tree
# - learning_rate: how much the model adjusts at each step
# - subsample : proprotion of the training data used for each round

# %%
caracteristicas_train, caracteristicas_test, price_train, price_test = train_test_split(
    caracteristicas, price, test_size=0.3, random_state=42)
price_train = price_train.ravel()  # Aplatir au cas où ce soit nécessaire
price_test = price_test.ravel()

model_XGBoost = XGBRegressor(objective='reg:squarederror', booster='gbtree')

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1],
    'subsample': [0.8, 1.0]
}

results = []

for n_estimators in param_grid['n_estimators']:
    for max_depth in param_grid['max_depth']:
        for learning_rate in param_grid['learning_rate']:
            for subsample in param_grid['subsample']:
                model_XGBoost = XGBRegressor(objective='reg:squarederror', booster='gbtree',
                                             n_estimators=n_estimators, max_depth=max_depth,
                                             learning_rate=learning_rate, subsample=subsample)

                model_XGBoost.fit(caracteristicas_train, price_train)

                #Train
                price_pred_train = model_XGBoost.predict(caracteristicas_train)

                mse_train = metrics.mean_squared_error(price_train, price_pred_train)
                rmse_train = np.sqrt(mse_train)
                r2_train = metrics.r2_score(price_train, price_pred_train)

                #Test
                price_pred_test = model_XGBoost.predict(caracteristicas_test)

                mse_test = metrics.mean_squared_error(price_test, price_pred_test)
                rmse_test = np.sqrt(mse_test)
                r2_test = metrics.r2_score(price_test, price_pred_test)

                results.append({
                    'n_estimators': n_estimators,
                    'max_depth': max_depth,
                    'learning_rate': learning_rate,
                    'subsample': subsample,
                    'train_mse': mse_train,
                    'train_rmse': rmse_train,
                    'train_r2': r2_train,
                    'test_mse': mse_test,
                    'test_rmse': rmse_test,
                    'test_r2': r2_test
                })

results_df = pd.DataFrame(results)

print("\nSummary of results:")
print(results_df)
# Out:
# Summary of results:
#     n_estimators  max_depth  learning_rate  subsample    train_mse  \
# 0            100          3           0.01        0.8  3556.508700
# 1            100          3           0.01        1.0  3565.040300
# 2            100          3           0.10        0.8  2363.629615
# 3            100          3           0.10        1.0  2363.663401
# 4            100          5           0.01        0.8  3179.526948
# 5            100          5           0.01        1.0  3196.134199
# 6            100          5           0.10        0.8  1945.042652
# 7            100          5           0.10        1.0  1959.530118
# 8            100          7           0.01        0.8  2849.193168
# 9            100          7           0.01        1.0  2874.192690
# 10           100          7           0.10        0.8  1423.087121
# 11           100          7           0.10        1.0  1494.723949
# 12           200          3           0.01        0.8  3069.910171
# 13           200          3           0.01        1.0  3074.816181
# 14           200          3           0.10        0.8  2177.062806
# 15           200          3           0.10        1.0  2198.641038
# 16           200          5           0.01        0.8  2654.102702
# 17           200          5           0.01        1.0  2659.836252
# 18           200          5           0.10        0.8  1658.323560
# 19           200          5           0.10        1.0  1750.082908
# 20           200          7           0.01        0.8  2240.211155
# 21           200          7           0.01        1.0  2257.828164
# 22           200          7           0.10        0.8   960.482346
# 23           200          7           0.10        1.0  1180.935541
#
#     train_rmse  train_r2     test_mse  test_rmse   test_r2
# 0    59.636471  0.290969  3644.215993  60.367342  0.286504
# 1    59.707958  0.289269  3658.022958  60.481592  0.283800
# 2    48.617174  0.528783  2418.398692  49.177217  0.526505
# 3    48.617522  0.528777  2438.905596  49.385277  0.522490
# 4    56.387294  0.366125  3305.957881  57.497460  0.352731
# 5    56.534363  0.362814  3322.985038  57.645338  0.349397
# 6    44.102638  0.612234  2266.456269  47.607313  0.556253
# 7    44.266580  0.609345  2277.124331  47.719224  0.554165
# 8    53.377834  0.431981  3108.453300  55.753505  0.391400
# 9    53.611498  0.426997  3138.410013  56.021514  0.385535
# 10   37.723827  0.716291  2236.416882  47.290770  0.562135
# 11   38.661660  0.702010  2258.290070  47.521470  0.557852
# 12   55.406770  0.387978  3153.662318  56.157478  0.382548
# 13   55.451025  0.387000  3163.054733  56.241041  0.380710
# 14   46.659006  0.565978  2294.616920  47.902160  0.550740
# 15   46.889669  0.561676  2317.526508  48.140695  0.546254
# 16   51.517984  0.470874  2803.365230  52.946815  0.451133
# 17   51.573600  0.469731  2812.507274  53.033077  0.449343
# 18   40.722519  0.669394  2233.971991  47.264913  0.562613
# 19   41.833992  0.651101  2241.595560  47.345491  0.561121
# 20   47.330869  0.553388  2603.847595  51.027910  0.490196
# 21   47.516609  0.549876  2624.272752  51.227656  0.486197
# 22   30.991650  0.808517  2258.229865  47.520836  0.557864
# 23   34.364743  0.764567  2259.492675  47.534121  0.557617

# %% [markdown]
# A good result is one where we have the smallest test rmse possible but also a small distance between the test rmse and train rmse to avoid overfitting.
#
# The smallest rmse with a small test-train difference is with parameters (line 14) :
# - n_estimators = 200
# - max_depth = 3
# - learning_rate = 0.1
# - subsample = 0.8
#
# With
# - train rmse = 46,65
# - test rmse = 47,9
#
# The results are better then with the linear regression model even though I would have expected a bigger difference.

# %% [markdown]
# #### XGBoost model with crossvalidation and the hyperparameters we found

# %%
model_XGBoost = XGBRegressor(objective='reg:squarederror', booster='gbtree',
                                             n_estimators=200, max_depth=3,
                                             learning_rate=0.1, subsample=0.8)
model_XGBoost.fit(caracteristicas_train, price_train)

# Cross-validation (5-folds)
cv_scores_mse = cross_val_score(model_XGBoost, caracteristicas_train, price_train, cv=5, scoring='neg_mean_squared_error')
cv_scores_rmse = np.sqrt(-cv_scores_mse)  # Convertir les scores MSE en RMSE

print(f"Cross-validation (training set) for current params:")
print(f"Mean RMSE (5-folds): {np.mean(cv_scores_rmse):.2f}")
print(f"Standard deviation of RMSE (5-folds): {np.std(cv_scores_rmse):.2f}")

#Train
# Predictions
price_pred_train = model_XGBoost.predict(caracteristicas_train)

# Result
mse = metrics.mean_squared_error(price_train, price_pred_train)
rmse = np.sqrt(mse)
r2 = metrics.r2_score(price_train, price_pred_train)

print("Train :")
print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
print(f"R² Score: {r2}")

#Test
# Predictions
price_pred_test = model_XGBoost.predict(caracteristicas_test)

# Result
mse = metrics.mean_squared_error(price_test, price_pred_test)
rmse = np.sqrt(mse)
r2 = metrics.r2_score(price_test, price_pred_test)

print("Test :")
print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
print(f"R² Score: {r2}")
# Out:
# Cross-validation (training set) for current params:
# Mean RMSE (5-folds): 49.01
# Standard deviation of RMSE (5-folds): 0.79
# Train :
# Mean Squared Error: 2177.062805504852
# Root Mean Squared Error: 46.65900562061789
# R² Score: 0.565977698977637
# Test :
# Mean Squared Error: 2294.6169203552063
# Root Mean Squared Error: 47.902159871504814
# R² Score: 0.5507398694695137

# %% [markdown]
# The cross-validation has a low standard deviation which is good.

# %% [markdown]
# ## Modelo 3 : Random Forest

# %% [markdown]
# #### Random forest model with crossfold validation

# %%
caracteristicas_train, caracteristicas_test, price_train, price_test = train_test_split(
    caracteristicas, price, test_size=0.3, random_state=42)

price_train = price_train.ravel()
price_test = price_test.ravel()

model_rf = RandomForestRegressor(n_estimators=100, random_state=42)

# Crossfold validation (5-folds)
cv_scores_mse = cross_val_score(model_rf, caracteristicas_train, price_train, cv=5, scoring='neg_mean_squared_error')
cv_scores_rmse = np.sqrt(-cv_scores_mse)  # Convertir les scores MSE en RMSE

# Results
print("Cross-validation (training set) :")
print(f"Mean RMSE (5-folds): {np.mean(cv_scores_rmse):.2f}")
print(f"Standard deviation of RMSE (5-folds): {np.std(cv_scores_rmse):.2f}")

model_rf.fit(caracteristicas_train, price_train)

#Train
price_pred_train = model_rf.predict(caracteristicas_train)

mse_train = metrics.mean_squared_error(price_train, price_pred_train)
rmse_train = np.sqrt(mse_train)
r2_train = metrics.r2_score(price_train, price_pred_train)

print("\nTrain :")
print(f"Mean Squared Error (MSE): {mse_train:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse_train:.2f}")
print(f"R² Score: {r2_train:.2f}")

#Test
price_pred_test = model_rf.predict(caracteristicas_test)

mse_test = metrics.mean_squared_error(price_test, price_pred_test)
rmse_test = np.sqrt(mse_test)
r2_test = metrics.r2_score(price_test, price_pred_test)

print("\nTest :")
print(f"Mean Squared Error (MSE): {mse_test:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse_test:.2f}")
print(f"R² Score: {r2_test:.2f}")
# Out:
# Cross-validation (training set) :
# Mean RMSE (5-folds): 50.85
# Standard deviation of RMSE (5-folds): 0.70
#
# Train :
# Mean Squared Error (MSE): 361.07
# Root Mean Squared Error (RMSE): 19.00
# R² Score: 0.93
#
# Test :
# Mean Squared Error (MSE): 2459.01
# Root Mean Squared Error (RMSE): 49.59
# R² Score: 0.52

# %% [markdown]
# With random forest we have a similar rmse then with XGBoost.
# The results are also better with training then with testing but with a much bigger difference which means we have an overfitting issue.
# We can try to improve that by modifying the hyper parameters.

# %% [markdown]
# #### Trying with different values of max_depth for the trees

# %%
caracteristicas_train, caracteristicas_test, price_train, price_test = train_test_split(
    caracteristicas, price, test_size=0.3, random_state=42)
price_train = price_train.ravel()
price_test = price_test.ravel()

max_depth_values = [5, 7, 9]
results = []

for max_depth in max_depth_values:
    print(f"\nTesting for max_depth = {max_depth}")

    model_rf = RandomForestRegressor(n_estimators=100, random_state=42, max_depth=max_depth)

    # Cross validation (5-folds)
    cv_scores_mse = cross_val_score(model_rf, caracteristicas_train, price_train, cv=5, scoring='neg_mean_squared_error')
    cv_scores_rmse = np.sqrt(-cv_scores_mse)

    print(f"Cross-validation (training set) for max_depth={max_depth}:")
    print(f"Mean RMSE (5-folds): {np.mean(cv_scores_rmse):.2f}")
    print(f"Standard deviation of RMSE (5-folds): {np.std(cv_scores_rmse):.2f}")

    model_rf.fit(caracteristicas_train, price_train)

    price_pred_train = model_rf.predict(caracteristicas_train)

    mse_train = metrics.mean_squared_error(price_train, price_pred_train)
    rmse_train = np.sqrt(mse_train)
    r2_train = metrics.r2_score(price_train, price_pred_train)

    price_pred_test = model_rf.predict(caracteristicas_test)

    mse_test = metrics.mean_squared_error(price_test, price_pred_test)
    rmse_test = np.sqrt(mse_test)
    r2_test = metrics.r2_score(price_test, price_pred_test)

    results.append({
        'max_depth': max_depth,
        'train_mse': mse_train,
        'train_rmse': rmse_train,
        'train_r2': r2_train,
        'test_mse': mse_test,
        'test_rmse': rmse_test,
        'test_r2': r2_test
    })

results_df = pd.DataFrame(results)

print("\nSummary of results:")
print(results_df)
# Out:
# Testing for max_depth = 5
# Cross-validation (training set) for max_depth=5:
# Mean RMSE (5-folds): 55.19
# Standard deviation of RMSE (5-folds): 0.90
#
# Testing for max_depth = 7
# Cross-validation (training set) for max_depth=7:
# Mean RMSE (5-folds): 52.94
# Standard deviation of RMSE (5-folds): 0.76
#
# Testing for max_depth = 9
# Cross-validation (training set) for max_depth=9:
# Mean RMSE (5-folds): 51.67
# Standard deviation of RMSE (5-folds): 0.65
#
# Summary of results:
#    max_depth    train_mse  train_rmse  train_r2     test_mse  test_rmse  \
# 0          5  2953.238173   54.343704  0.411238  3057.195539  55.291912
# 1          7  2516.988846   50.169601  0.498210  2788.035281  52.801849
# 2          9  2060.946491   45.397649  0.589127  2625.773384  51.242301
#
#     test_r2
# 0  0.401436
# 1  0.454134
# 2  0.485903

# %% [markdown]
# The rmse is higher for a smaller maximal depth, but it reduces the overfitting.
#
# The parameters max_depth = 7 seem like good a option to keep the rmse test value not to high while also not having a model that overfits the training data.
#
# We have train rmse = 50.16 and test rmse = 52.80 which is a little bit worse then the two previous models. But limiting the depth to 7 for exemple is a good way to avoid overfiting.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Result for each model with the most efficient hyperparameters that were found :
#
#
# |**Model**                   |**RMSE test**|**RMSE train**|**R²**  |
# |----------------------------|-------------|--------------|--------|
# | Model 1 (Linear Regression)| 50.60       | 49.44        | 0.5142 |
# | Model 2 (XGBoost)          | 46.65       | 47.90        | 0.5507 |
# | Model 3 (Random Forest)    | 50.16       | 52.80        | 0.4982 |

# %% [markdown]
# Between the tree models that we tried, with the way we cleaned and transformed the data the most efficient one is XGBoost.
#
# The most efficient hyperparameters for this model were :
# - n_estimators = 200
# - max_depth = 3
# - learning_rate = 0.1
# - subsample = 0.8

# %%
models = ['Linear Regression', 'XGBoost', 'Random Forest']
rmse_test = [50.60, 46.65, 50.16]
rmse_train = [49.44, 47.90, 52.80]
r2 = [0.5142, 0.5507, 0.4982]

x = range(len(models))

plt.figure(figsize=(10, 6))

plt.plot(x, rmse_test, label='RMSE Test', marker='o')
plt.plot(x, rmse_train, label='RMSE Train', marker='o')

plt.xticks(x, models)
plt.ylabel('RMSE')
plt.title('Comparison of Model Performance')
plt.legend()

plt.show()
